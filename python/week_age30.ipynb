# %%
import time
import pandas as pd
import urllib.request
import requests
import bs4
from collections import Counter
import konlpy
from konlpy.tag import Hannanum
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
tagger=Hannanum()
check = ['경향신문','국민일보','동아일보','문화일보','서울신문','세계일보','조선일보','중앙일보','한겨레','한국일보','뉴스1','뉴시스','연합뉴스','채널A','한국경제TV','JTBC','KBS','MBC','MBN','SBS','TV조선','YTN','노컷뉴스','데일리안','미디어오늘','아이뉴스24','오마이뉴스','프레시안','디지털데일리','디지털타임스','블로터','전자신문','ZDNet Korea']
stopwords = ['단독','논란','구독','뉴스','채널','네이버','연합뉴스','금지','재배포','오후','오전','이후','이날','사진','콘텐츠','영상편집','영상취재','기자','만원','때문']

# %%
age = "age30"

# %%
folder1 = "C:/marketing4/" + age + "/" + age + "_1"
folder2 = "C:/marketing4/" + age + "/" + age + "_2"
folder3 = "C:/marketing4/" + age + "/" + age + "_3"
foldert = "C:/marketing4/" + age + "/" + age + "_t"

# %%
data = pd.read_excel(foldert + "/" + age + ".xlsx")
data
# Out:
#              날짜        실검
# 0    2021-03-04  71.02335
# 1    2021-03-05  63.39860
# 2    2021-03-06  43.22425
# 3    2021-03-07  37.36256
# 4    2021-03-08  40.12751
# ..          ...       ...
# 793  2023-05-06   1.50283
# 794  2023-05-07   1.58740
# 795  2023-05-08   7.81341
# 796  2023-05-09   8.84783
# 797  2023-05-10   8.62012
#
# [798 rows x 2 columns]

# %%
a2 = list(data['실검'])
b2 = []
c2 = []
for i, v in enumerate(a2):
    b2.append([v, i])
    if i % 7 == 6:
        c2.append(max(b2)[1])
        b2 = []
print(c2[:5])
# Out:
# [0, 8, 19, 21, 29]

# %%
df2 = data.loc[c2, :]
df2
# Out:
#              날짜        실검
# 0    2021-03-04  71.02335
# 8    2021-03-12  34.15522
# 19   2021-03-23  52.68362
# 21   2021-03-25  27.94873
# 29   2021-04-02  17.82577
# ..          ...       ...
# 768  2023-04-11   2.32906
# 776  2023-04-19   2.63483
# 777  2023-04-20  13.59052
# 784  2023-04-27   2.51122
# 796  2023-05-09   8.84783
#
# [114 rows x 2 columns]

# %%
df3 = df2.sort_values('실검', ascending = False, ignore_index = True)
df3
# Out:
#              날짜         실검
# 0    2021-05-05  100.00000
# 1    2021-10-25   81.53015
# 2    2022-10-15   78.50497
# 3    2021-03-04   71.02335
# 4    2021-03-23   52.68362
# ..          ...        ...
# 109  2023-04-11    2.32906
# 110  2023-03-24    2.26400
# 111  2022-08-11    2.19894
# 112  2022-12-13    2.07533
# 113  2022-12-15    1.84763
#
# [114 rows x 2 columns]

# %%
w = list(df3['실검'].apply(lambda x:x/100))
w[:10]
# Out:
# [1.0,
#  0.8153015,
#  0.7850497,
#  0.7102335,
#  0.5268362,
#  0.3415522,
#  0.2890508,
#  0.2842365,
#  0.2794873,
#  0.244161]

# %%
d = []
for i in range(len(df3)):
    d.append(str(df3.loc[i, '날짜'])[:10].replace("-",""))
d[:5]
# Out:
# ['20210505', '20211025', '20221015', '20210304', '20210323']

# %%
e = []
for n, y in enumerate(d):
    e.append((n,y))
e[:10]
# Out:
# [(0, '20210505'),
#  (1, '20211025'),
#  (2, '20221015'),
#  (3, '20210304'),
#  (4, '20210323'),
#  (5, '20210312'),
#  (6, '20211018'),
#  (7, '20221030'),
#  (8, '20210325'),
#  (9, '20210417')]

# %%
error = []
for n, y in e:
    print("n =", n, "y =", y)
    url = "https://news.naver.com/main/ranking/popularDay.naver?date=" + y
    headers = {'User-agent' : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/113.0.0.0 Safari/537.36'}
    html = requests.get(url, headers = headers)
    time.sleep(5)

    bs_obj = bs4.BeautifulSoup(html.content, "html.parser")
    div = bs_obj.findAll("div", {"class":"rankingnews_box"})

    k=1
    data=[]
    col = ['No','Date','Publisher','Rank','Title','URL']

    for i in div:
        publisher = i.find("strong", {"class":"rankingnews_name"})
        if publisher.text in check:
            ul = i.find("ul", {"class":"rankingnews_list"})
            lis = ul.findAll("li")
            for j in lis:
                em_tag = j.find("em")
                a_tag = j.find("a")

                if (a_tag != None) and (em_tag != None):
                    article_url = a_tag['href']
                    row = [k, y, publisher.text, em_tag.text, a_tag.text, article_url]
                    data.append(row)
                    k += 1

    df = pd.DataFrame(data, columns = col)
    df.to_csv(folder1 + '/df' + str(n) + '.csv', encoding = 'utf-8-sig')
    if len(df) == 0:
        print("ERROR1")
        error.append(1)
    else:
        print("Done")
        error.append(0)
# Out:
# n = 0 y = 20210505
# Done
# n = 1 y = 20211025
# Done
# n = 2 y = 20221015
# Done
# n = 3 y = 20210304
# Done
# n = 4 y = 20210323
# Done
# n = 5 y = 20210312
# Done
# n = 6 y = 20211018
# ERROR1
# n = 7 y = 20221030
# Done
# n = 8 y = 20210325
# Done
# n = 9 y = 20210417
# Done
# n = 10 y = 20210412
# Done
# n = 11 y = 20210506
# Done
# n = 12 y = 20210402
# Done
# n = 13 y = 20211123
# Done
# n = 14 y = 20230129
# Done
# n = 15 y = 20211005
# Done
# n = 16 y = 20210607
# Done
# n = 17 y = 20210426
# ERROR1
# n = 18 y = 20221230
# Done
# n = 19 y = 20210513
# Done
# n = 20 y = 20230420
# Done
# n = 21 y = 20220615
# Done
# n = 22 y = 20211214
# Done
# n = 23 y = 20220608
# Done
# n = 24 y = 20210531
# ERROR1
# n = 25 y = 20220207
# Done
# n = 26 y = 20210520
# Done
# n = 27 y = 20210611
# Done
# n = 28 y = 20221004
# Done
# n = 29 y = 20220224
# ERROR1
# n = 30 y = 20210716
# Done
# n = 31 y = 20220109
# Done
# n = 32 y = 20220708
# Done
# n = 33 y = 20220101
# Done
# n = 34 y = 20210911
# Done
# n = 35 y = 20220310
# Done
# n = 36 y = 20230509
# Done
# n = 37 y = 20211216
# Done
# n = 38 y = 20210617
# ERROR1
# n = 39 y = 20210811
# ERROR1
# n = 40 y = 20210710
# Done
# n = 41 y = 20210630
# ERROR1
# n = 42 y = 20210812
# Done
# n = 43 y = 20230109
# Done
# n = 44 y = 20210703
# Done
# n = 45 y = 20210902
# Done
# n = 46 y = 20220211
# ERROR1
# n = 47 y = 20210802
# Done
# n = 48 y = 20220122
# Done
# n = 49 y = 20211104
# Done
# n = 50 y = 20210728
# Done
# n = 51 y = 20210825
# Done
# n = 52 y = 20211201
# Done
# n = 53 y = 20220116
# Done
# n = 54 y = 20211204
# Done
# n = 55 y = 20220523
# Done
# n = 56 y = 20220911
# Done
# n = 57 y = 20220808
# ERROR1
# n = 58 y = 20210830
# Done
# n = 59 y = 20220307
# Done
# n = 60 y = 20220616
# ERROR1
# n = 61 y = 20211028
# ERROR1
# n = 62 y = 20220222
# ERROR1
# n = 63 y = 20211229
# ERROR1
# n = 64 y = 20221129
# Done
# n = 65 y = 20211112
# Done
# n = 66 y = 20211008
# Done
# n = 67 y = 20210923
# Done
# n = 68 y = 20220830
# Done
# n = 69 y = 20210916
# Done
# n = 70 y = 20220514
# ERROR1
# n = 71 y = 20220529
# Done
# n = 72 y = 20221006
# ERROR1
# n = 73 y = 20221203
# Done
# n = 74 y = 20221115
# Done
# n = 75 y = 20220201
# Done
# n = 76 y = 20221228
# Done
# n = 77 y = 20220926
# Done
# n = 78 y = 20230117
# Done
# n = 79 y = 20220317
# ERROR1
# n = 80 y = 20220630
# Done
# n = 81 y = 20220629
# Done
# n = 82 y = 20221106
# Done
# n = 83 y = 20230204
# Done
# n = 84 y = 20220507
# Done
# n = 85 y = 20220725
# Done
# n = 86 y = 20220401
# ERROR1
# n = 87 y = 20230404
# ERROR1
# n = 88 y = 20221122
# Done
# n = 89 y = 20220802
# Done
# n = 90 y = 20220421
# Done
# n = 91 y = 20220324
# ERROR1
# n = 92 y = 20220410
# Done
# n = 93 y = 20221025
# Done
# n = 94 y = 20220905
# Done
# n = 95 y = 20230310
# Done
# n = 96 y = 20220416
# Done
# n = 97 y = 20230302
# Done
# n = 98 y = 20230209
# Done
# n = 99 y = 20220719
# ERROR1
# n = 100 y = 20220819
# Done
# n = 101 y = 20220428
# ERROR1
# n = 102 y = 20230419
# Done
# n = 103 y = 20230227
# Done
# n = 104 y = 20220916
# Done
# n = 105 y = 20230427
# Done
# n = 106 y = 20230222
# Done
# n = 107 y = 20230125
# Done
# n = 108 y = 20230322
# Done
# n = 109 y = 20230411
# Done
# n = 110 y = 20230324
# Done
# n = 111 y = 20220811
# Done
# n = 112 y = 20221213
# Done
# n = 113 y = 20221215
# Done

# %%
retry = [e[i] for i in range(len(error)) if error[i] == 1]
print(len(retry))
print("="*25)
print(retry)
# Out:
# 21
# =========================
# [(6, '20211018'), (17, '20210426'), (24, '20210531'), (29, '20220224'), (38, '20210617'), (39, '20210811'), (41, '20210630'), (46, '20220211'), (57, '20220808'), (60, '20220616'), (61, '20211028'), (62, '20220222'), (63, '20211229'), (70, '20220514'), (72, '20221006'), (79, '20220317'), (86, '20220401'), (87, '20230404'), (91, '20220324'), (99, '20220719'), (101, '20220428')]

# %%
error2 = []
for n, y in retry:
    print("n =", n, "y =", y)
    url = "https://news.naver.com/main/ranking/popularDay.naver?date=" + y
    headers = {'User-agent' : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/113.0.0.0 Safari/537.36'}
    html = requests.get(url, headers = headers)
    time.sleep(5)

    bs_obj = bs4.BeautifulSoup(html.content, "html.parser")
    div = bs_obj.findAll("div", {"class":"rankingnews_box"})

    k=1
    data=[]
    col = ['No','Date','Publisher','Rank','Title','URL']

    for i in div:
        publisher = i.find("strong", {"class":"rankingnews_name"})
        if publisher.text in check:
            ul = i.find("ul", {"class":"rankingnews_list"})
            lis = ul.findAll("li")
            for j in lis:
                em_tag = j.find("em")
                a_tag = j.find("a")

                if (a_tag != None) and (em_tag != None):
                    article_url = a_tag['href']
                    row = [k, y, publisher.text, em_tag.text, a_tag.text, article_url]
                    data.append(row)
                    k += 1

    df = pd.DataFrame(data, columns = col)
    df.to_csv(folder1 + '/df' + str(n) + '.csv', encoding = 'utf-8-sig')
    if len(df) == 0:
        print("ERROR1")
        error2.append(1)
    else:
        print("Done")
        error2.append(0)
# Out:
# n = 6 y = 20211018
# Done
# n = 17 y = 20210426
# Done
# n = 24 y = 20210531
# Done
# n = 29 y = 20220224
# Done
# n = 38 y = 20210617
# Done
# n = 39 y = 20210811
# Done
# n = 41 y = 20210630
# Done
# n = 46 y = 20220211
# Done
# n = 57 y = 20220808
# Done
# n = 60 y = 20220616
# Done
# n = 61 y = 20211028
# Done
# n = 62 y = 20220222
# Done
# n = 63 y = 20211229
# ERROR1
# n = 70 y = 20220514
# Done
# n = 72 y = 20221006
# ERROR1
# n = 79 y = 20220317
# Done
# n = 86 y = 20220401
# ERROR1
# n = 87 y = 20230404
# Done
# n = 91 y = 20220324
# Done
# n = 99 y = 20220719
# ERROR1
# n = 101 y = 20220428
# Done

# %%
retry2 = [retry[i] for i in range(len(error2)) if error2[i] == 1]
print(len(retry2))
print("="*25)
print(retry2)
# Out:
# 4
# =========================
# [(63, '20211229'), (72, '20221006'), (86, '20220401'), (99, '20220719')]

# %%
error3 = []
for n, y in retry2:
    print("n =", n, "y =", y)
    url = "https://news.naver.com/main/ranking/popularDay.naver?date=" + y
    headers = {'User-agent' : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/113.0.0.0 Safari/537.36'}
    html = requests.get(url, headers = headers)
    time.sleep(5)

    bs_obj = bs4.BeautifulSoup(html.content, "html.parser")
    div = bs_obj.findAll("div", {"class":"rankingnews_box"})

    k=1
    data=[]
    col = ['No','Date','Publisher','Rank','Title','URL']

    for i in div:
        publisher = i.find("strong", {"class":"rankingnews_name"})
        if publisher.text in check:
            ul = i.find("ul", {"class":"rankingnews_list"})
            lis = ul.findAll("li")
            for j in lis:
                em_tag = j.find("em")
                a_tag = j.find("a")

                if (a_tag != None) and (em_tag != None):
                    article_url = a_tag['href']
                    row = [k, y, publisher.text, em_tag.text, a_tag.text, article_url]
                    data.append(row)
                    k += 1

    df = pd.DataFrame(data, columns = col)
    df.to_csv(folder1 + '/df' + str(n) + '.csv', encoding = 'utf-8-sig')
    if len(df) == 0:
        print("ERROR1")
        error3.append(1)
    else:
        print("Done")
        error3.append(0)
# Out:
# n = 63 y = 20211229
# Done
# n = 72 y = 20221006
# Done
# n = 86 y = 20220401
# ERROR1
# n = 99 y = 20220719
# Done

# %%
retry3 = [retry2[i] for i in range(len(error3)) if error3[i] == 1]
print(len(retry3))
print("="*25)
print(retry3)
# Out:
# 1
# =========================
# [(86, '20220401')]

# %%
for n, y in [(86, '20220401')]:
    print("n =", n, "y =", y)
    url = "https://news.naver.com/main/ranking/popularDay.naver?date=" + y
    headers = {'User-agent' : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/113.0.0.0 Safari/537.36'}
    html = requests.get(url, headers = headers)
    time.sleep(5)

    bs_obj = bs4.BeautifulSoup(html.content, "html.parser")
    div = bs_obj.findAll("div", {"class":"rankingnews_box"})

    k=1
    data=[]
    col = ['No','Date','Publisher','Rank','Title','URL']

    for i in div:
        publisher = i.find("strong", {"class":"rankingnews_name"})
        if publisher.text in check:
            ul = i.find("ul", {"class":"rankingnews_list"})
            lis = ul.findAll("li")
            for j in lis:
                em_tag = j.find("em")
                a_tag = j.find("a")

                if (a_tag != None) and (em_tag != None):
                    article_url = a_tag['href']
                    row = [k, y, publisher.text, em_tag.text, a_tag.text, article_url]
                    data.append(row)
                    k += 1

    df = pd.DataFrame(data, columns = col)
    df.to_csv(folder1 + '/df' + str(n) + '.csv', encoding = 'utf-8-sig')
    if len(df) == 0:
        print("ERROR1")
        #error3.append(1)
    else:
        print("Done")
        #error3.append(0)
# Out:
# n = 86 y = 20220401
# Done

# %%
url = []
date = []
total = 0
for i in range(len(e)):
    news = pd.read_csv(folder1 + '/df' + str(i) + ".csv", encoding="utf-8-sig")
    date.extend(news["Date"])
    url.extend(news["URL"])
    total += len(news["URL"])

# %%
print(total)
print(len(date))
print(len(url))
# Out:
# 18760
# 18760
# 18760

# %%
print(date[:5])
print("=" * 30)
print(url[:2])
print("=" * 30)
# Out:
# [20210505, 20210505, 20210505, 20210505, 20210505]
# ==============================
# ['https://n.news.naver.com/article/047/0002311755?ntype=RANKING', 'https://n.news.naver.com/article/047/0002311745?ntype=RANKING']
# ==============================

# %%
news_url = []
for n, y in enumerate(url):
    news_url.append((n,y))
num = len(news_url)
print(num)
# Out:
# 18760

# %%
news_url[:2]
# Out:
# [(0, 'https://n.news.naver.com/article/047/0002311755?ntype=RANKING'),
#  (1, 'https://n.news.naver.com/article/047/0002311745?ntype=RANKING')]

# %%
con_error = []
con = []

# %%
for idx, u in news_url:
    print("idx =", idx)
    headers = {'User-agent' : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/113.0.0.0 Safari/537.36'}
    try:
        html = requests.get(u, headers = headers, timeout = 5)
    except:
        print("TimeOut ERROR")
        con.append([idx, " "])
        df = pd.DataFrame(con, columns = ["idx",'Contents'])
        df.to_csv(folder2 + '/df_con' + str(idx) + '.csv', encoding = 'utf-8-sig')
        con_error.append((idx, 3))
        time.sleep(300)
    else:
        time.sleep(1)
        bs_obj = bs4.BeautifulSoup(html.content, "html.parser")
        body = bs_obj.find("div", {"id":"newsct_article","class":"newsct_article _article_body"})
        if body != None:
            contents = body.text.replace('\n','')
            if len(contents) == 0:
                print("ERROR2")
                title = bs_obj.find("h2", {"id":"title_area", "class":"media_end_head_headline"})
                con.append([idx, title.text])
                df = pd.DataFrame(con, columns = ["idx",'Contents'])
                df.to_csv(folder2 + '/df_con' + str(idx) + '.csv', encoding = 'utf-8-sig')
                con_error.append((idx, 2))
                continue
            else: con.append([idx, contents])
        else:
            print("ERROR1")
            con.append([idx, " "])
            df = pd.DataFrame(con, columns = ["idx",'Contents'])
            df.to_csv(folder2 + '/df_con' + str(idx) + '.csv', encoding = 'utf-8-sig')
            con_error.append((idx, 1))
            continue
        if idx >= num-5:
            df = pd.DataFrame(con, columns = ["idx",'Contents'])
            df.to_csv(folder2 + '/df_con' + str(idx) + '.csv', encoding = 'utf-8-sig')
        print("Done")
        con_error.append((idx, 0))
# Out:
# idx = 0
# Done
# idx = 1
# Done
# idx = 2
# Done
# idx = 3
# Done
# idx = 4
# Done
# idx = 5
# Done
# idx = 6
# Done
# idx = 7
# Done
# idx = 8
# Done
# idx = 9
# Done
# idx = 10
# Done
# idx = 11
# Done
# idx = 12
# Done
# idx = 13
# Done
# idx = 14
# Done
# idx = 15
# Done
# idx = 16
# Done
# idx = 17
# Done
# idx = 18
# Done
# idx = 19
# Done
# idx = 20
# Done
# idx = 21
# Done
# idx = 22
# Done
# idx = 23
# Done
# idx = 24
# Done
# idx = 25
# Done
# idx = 26
# Done
# idx = 27
# Done
# idx = 28
# Done
# idx = 29
# Done
# idx = 30
# Done
# idx = 31
# Done
# idx = 32
# Done
# idx = 33
# Done
# idx = 34
# Done
# idx = 35
# Done
# idx = 36
# Done
# idx = 37
# Done
# idx = 38
# Done
# idx = 39
# Done
# idx = 40
# Done
# idx = 41
# Done
# idx = 42
# Done
# idx = 43
# Done
# idx = 44
# Done
# idx = 45
# Done
# idx = 46
# Done
# idx = 47
# Done
# idx = 48
# Done
# idx = 49
# Done
# idx = 50
# Done
# idx = 51
# Done
# idx = 52
# Done
# idx = 53
# Done
# idx = 54
# Done
# idx = 55
# Done
# idx = 56
# Done
# idx = 57
# Done
# idx = 58
# Done
# idx = 59
# Done
# idx = 60
# Done
# idx = 61
# Done
# idx = 62
# Done
# idx = 63
# Done
# idx = 64
# Done
# idx = 65
# Done
# idx = 66
# Done
# idx = 67
# Done
# idx = 68
# Done
# idx = 69
# Done
# idx = 70
# Done
# idx = 71
# Done
# idx = 72
# Done
# idx = 73
# Done
# idx = 74
# Done
# idx = 75
# Done
# idx = 76
# Done
# idx = 77
# Done
# idx = 78
# Done
# idx = 79
# Done
# idx = 80
# Done
# idx = 81
# Done
# idx = 82
# Done
# idx = 83
# Done
# idx = 84
# Done
# idx = 85
# Done
# idx = 86
# Done
# idx = 87
# Done
# idx = 88
# Done
# idx = 89
# Done
# idx = 90
# Done
# idx = 91
# Done
# idx = 92
# Done
# idx = 93
# Done
# idx = 94
# Done
# idx = 95
# Done
# idx = 96
# Done
# idx = 97
# Done
# idx = 98
# Done
# idx = 99
# Done
# idx = 100
# Done
# idx = 101
# Done
# idx = 102
# Done
# idx = 103
# Done
# idx = 104
# Done
# idx = 105
# Done
# idx = 106
# Done
# idx = 107
# Done
# idx = 108
# Done
# idx = 109
# Done
# idx = 110
# Done
# idx = 111
# Done
# idx = 112
# Done
# idx = 113
# Done
# idx = 114
# Done
# idx = 115
# Done
# idx = 116
# Done
# idx = 117
# Done
# idx = 118
# Done
# idx = 119
# Done
# idx = 120
# Done
# idx = 121
# Done
# idx = 122
# Done
# idx = 123
# Done
# idx = 124
# Done
# idx = 125
# Done
# idx = 126
# Done
# idx = 127
# Done
# idx = 128
# Done
# idx = 129
# Done
# idx = 130
# Done
# idx = 131
# Done
# idx = 132
# Done
# idx = 133
# Done
# idx = 134
# Done
# idx = 135
# Done
# idx = 136
# Done
# idx = 137
# Done
# idx = 138
# Done
# idx = 139
# Done
# idx = 140
# Done
# idx = 141
# Done
# idx = 142
# Done
# idx = 143
# Done
# idx = 144
# Done
# idx = 145
# Done
# idx = 146
# Done
# idx = 147
# Done
# idx = 148
# Done
# idx = 149
# Done
# idx = 150
# Done
# idx = 151
# Done
# idx = 152
# Done
# idx = 153
# Done
# idx = 154
# Done
# idx = 155
# Done
# idx = 156
# Done
# idx = 157
# Done
# idx = 158
# Done
# idx = 159
# Done
# idx = 160
# Done
# idx = 161
# Done
# idx = 162
# Done
# idx = 163
# Done
# idx = 164
# Done
# idx = 165
# Done
# idx = 166
# Done
# idx = 167
# Done
# idx = 168
# Done
# idx = 169
# Done
# idx = 170
# Done
# idx = 171
# Done
# idx = 172
# Done
# idx = 173
# Done
# idx = 174
# Done
# idx = 175
# Done
# idx = 176
# Done
# idx = 177
# Done
# idx = 178
# Done
# idx = 179
# Done
# idx = 180
# Done
# idx = 181
# Done
# idx = 182
# Done
# idx = 183
# Done
# idx = 184
# Done
# idx = 185
# Done
# idx = 186
# Done
# idx = 187
# Done
# idx = 188
# Done
# idx = 189
# Done
# idx = 190
# Done
# idx = 191
# Done
# idx = 192
# Done
# idx = 193
# Done
# idx = 194
# Done
# idx = 195
# Done
# idx = 196
# Done
# idx = 197
# Done
# idx = 198
# Done
# idx = 199
# Done
# idx = 200
# Done
# idx = 201
# Done
# idx = 202
# Done
# idx = 203
# Done
# idx = 204
# Done
# idx = 205
# Done
# idx = 206
# Done
# idx = 207
# Done
# idx = 208
# Done
# idx = 209
# Done
# idx = 210
# Done
# idx = 211
# Done
# idx = 212
# Done
# idx = 213
# Done
# idx = 214
# Done
# idx = 215
# Done
# idx = 216
# Done
# idx = 217
# Done
# idx = 218
# Done
# idx = 219
# Done
# idx = 220
# Done
# idx = 221
# Done
# idx = 222
# Done
# idx = 223
# Done
# idx = 224
# Done
# idx = 225
# Done
# idx = 226
# Done
# idx = 227
# Done
# idx = 228
# Done
# idx = 229
# Done
# idx = 230
# Done
# idx = 231
# Done
# idx = 232
# Done
# idx = 233
# Done
# idx = 234
# Done
# idx = 235
# Done
# idx = 236
# Done
# idx = 237
# Done
# idx = 238
# Done
# idx = 239
# Done
# idx = 240
# Done
# idx = 241
# Done
# idx = 242
# Done
# idx = 243
# Done
# idx = 244
# Done
# idx = 245
# Done
# idx = 246
# Done
# idx = 247
# Done
# idx = 248
# ERROR1
# idx = 249
# Done
# idx = 250
# Done
# idx = 251
# Done
# idx = 252
# Done
# idx = 253
# Done
# idx = 254
# Done
# idx = 255
# Done
# idx = 256
# Done
# idx = 257
# Done
# idx = 258
# Done
# idx = 259
# Done
# idx = 260
# Done
# idx = 261
# Done
# idx = 262
# Done
# idx = 263
# Done
# idx = 264
# Done
# idx = 265
# Done
# idx = 266
# Done
# idx = 267
# Done
# idx = 268
# Done
# idx = 269
# Done
# idx = 270
# Done
# idx = 271
# Done
# idx = 272
# Done
# idx = 273
# Done
# idx = 274
# Done
# idx = 275
# Done
# idx = 276
# Done
# idx = 277
# Done
# idx = 278
# Done
# idx = 279
# Done
# idx = 280
# Done
# idx = 281
# Done
# idx = 282
# Done
# idx = 283
# Done
# idx = 284
# Done
# idx = 285
# Done
# idx = 286
# Done
# idx = 287
# Done
# idx = 288
# Done
# idx = 289
# Done
# idx = 290
# Done
# idx = 291
# Done
# idx = 292
# Done
# idx = 293
# Done
# idx = 294
# Done
# idx = 295
# Done
# idx = 296
# Done
# idx = 297
# Done
# idx = 298
# Done
# idx = 299
# Done
# idx = 300
# Done
# idx = 301
# Done
# idx = 302
# Done
# idx = 303
# Done
# idx = 304
# Done
# idx = 305
# Done
# idx = 306
# Done
# idx = 307
# Done
# idx = 308
# Done
# idx = 309
# Done
# idx = 310
# Done
# idx = 311
# Done
# idx = 312
# Done
# idx = 313
# Done
# idx = 314
# Done
# idx = 315
# Done
# idx = 316
# Done
# idx = 317
# Done
# idx = 318
# Done
# idx = 319
# Done
# idx = 320
# Done
# idx = 321
# Done
# idx = 322
# Done
# idx = 323
# Done
# idx = 324
# Done
# idx = 325
# Done
# idx = 326
# Done
# idx = 327
# Done
# idx = 328
# Done
# idx = 329
# Done
# idx = 330
# Done
# idx = 331
# Done
# idx = 332
# Done
# idx = 333
# Done
# idx = 334
# Done
# idx = 335
# Done
# idx = 336
# Done
# idx = 337
# Done
# idx = 338
# Done
# idx = 339
# Done
# idx = 340
# Done
# idx = 341
# Done
# idx = 342
# Done
# idx = 343
# Done
# idx = 344
# Done
# idx = 345
# Done
# idx = 346
# Done
# idx = 347
# Done
# idx = 348
# Done
# idx = 349
# Done
# idx = 350
# Done
# idx = 351
# Done
# idx = 352
# Done
# idx = 353
# Done
# idx = 354
# Done
# idx = 355
# Done
# idx = 356
# Done
# idx = 357
# Done
# idx = 358
# Done
# idx = 359
# Done
# idx = 360
# Done
# idx = 361
# Done
# idx = 362
# Done
# idx = 363
# Done
# idx = 364
# Done
# idx = 365
# Done
# idx = 366
# Done
# idx = 367
# Done
# idx = 368
# Done
# idx = 369
# Done
# idx = 370
# Done
# idx = 371
# Done
# idx = 372
# Done
# idx = 373
# Done
# idx = 374
# Done
# idx = 375
# Done
# idx = 376
# Done
# idx = 377
# Done
# idx = 378
# Done
# idx = 379
# Done
# idx = 380
# Done
# idx = 381
# Done
# idx = 382
# Done
# idx = 383
# Done
# idx = 384
# Done
# idx = 385
# Done
# idx = 386
# Done
# idx = 387
# Done
# idx = 388
# Done
# idx = 389
# Done
# idx = 390
# Done
# idx = 391
# Done
# idx = 392
# Done
# idx = 393
# Done
# idx = 394
# Done
# idx = 395
# Done
# idx = 396
# Done
# idx = 397
# Done
# idx = 398
# Done
# idx = 399
# Done
# idx = 400
# Done
# idx = 401
# Done
# idx = 402
# Done
# idx = 403
# Done
# idx = 404
# Done
# idx = 405
# Done
# idx = 406
# Done
# idx = 407
# Done
# idx = 408
# Done
# idx = 409
# Done
# idx = 410
# Done
# idx = 411
# Done
# idx = 412
# Done
# idx = 413
# Done
# idx = 414
# Done
# idx = 415
# Done
# idx = 416
# Done
# idx = 417
# Done
# idx = 418
# Done
# idx = 419
# Done
# idx = 420
# Done
# idx = 421
# Done
# idx = 422
# Done
# idx = 423
# Done
# idx = 424
# Done
# idx = 425
# Done
# idx = 426
# Done
# idx = 427
# Done
# idx = 428
# Done
# idx = 429
# Done
# idx = 430
# Done
# idx = 431
# Done
# idx = 432
# Done
# idx = 433
# Done
# idx = 434
# Done
# idx = 435
# Done
# idx = 436
# Done
# idx = 437
# Done
# idx = 438
# Done
# idx = 439
# Done
# idx = 440
# Done
# idx = 441
# Done
# idx = 442
# Done
# idx = 443
# Done
# idx = 444
# Done
# idx = 445
# Done
# idx = 446
# Done
# idx = 447
# Done
# idx = 448
# Done
# idx = 449
# Done
# idx = 450
# Done
# idx = 451
# Done
# idx = 452
# Done
# idx = 453
# Done
# idx = 454
# Done
# idx = 455
# Done
# idx = 456
# Done
# idx = 457
# Done
# idx = 458
# Done
# idx = 459
# Done
# idx = 460
# Done
# idx = 461
# Done
# idx = 462
# Done
# idx = 463
# Done
# idx = 464
# Done
# idx = 465
# Done
# idx = 466
# Done
# idx = 467
# Done
# idx = 468
# Done
# idx = 469
# Done
# idx = 470
# Done
# idx = 471
# Done
# idx = 472
# Done
# idx = 473
# Done
# idx = 474
# Done
# idx = 475
# Done
# idx = 476
# Done
# idx = 477
# Done
# idx = 478
# Done
# idx = 479
# Done
# idx = 480
# Done
# idx = 481
# Done
# idx = 482
# Done
# idx = 483
# Done
# idx = 484
# Done
# idx = 485
# Done
# idx = 486
# Done
# idx = 487
# Done
# idx = 488
# Done
# idx = 489
# Done
# idx = 490
# Done
# idx = 491
# Done
# idx = 492
# Done
# idx = 493
# Done
# idx = 494
# Done
# idx = 495
# Done
# idx = 496
# Done
# idx = 497
# Done
# idx = 498
# Done
# idx = 499
# Done
# idx = 500
# Done
# idx = 501
# Done
# idx = 502
# Done
# idx = 503
# Done
# idx = 504
# Done
# idx = 505
# Done
# idx = 506
# Done
# idx = 507
# Done
# idx = 508
# Done
# idx = 509
# Done
# idx = 510
# Done
# idx = 511
# Done
# idx = 512
# Done
# idx = 513
# Done
# idx = 514
# Done
# idx = 515
# Done
# idx = 516
# Done
# idx = 517
# Done
# idx = 518
# Done
# idx = 519
# Done
# idx = 520
# Done
# idx = 521
# Done
# idx = 522
# Done
# idx = 523
# Done
# idx = 524
# Done
# idx = 525
# Done
# idx = 526
# Done
# idx = 527
# Done
# idx = 528
# Done
# idx = 529
# Done
# idx = 530
# Done
# idx = 531
# Done
# idx = 532
# Done
# idx = 533
# Done
# idx = 534
# Done
# idx = 535
# Done
# idx = 536
# Done
# idx = 537
# Done
# idx = 538
# Done
# idx = 539
# Done
# idx = 540
# Done
# idx = 541
# Done
# idx = 542
# Done
# idx = 543
# Done
# idx = 544
# Done
# idx = 545
# Done
# idx = 546
# Done
# idx = 547
# Done
# idx = 548
# Done
# idx = 549
# Done
# idx = 550
# Done
# idx = 551
# Done
# idx = 552
# Done
# idx = 553
# Done
# idx = 554
# Done
# idx = 555
# Done
# idx = 556
# Done
# idx = 557
# Done
# idx = 558
# Done
# idx = 559
# Done
# idx = 560
# Done
# idx = 561
# Done
# idx = 562
# Done
# idx = 563
# Done
# idx = 564
# Done
# idx = 565
# Done
# idx = 566
# Done
# idx = 567
# Done
# idx = 568
# Done
# idx = 569
# Done
# idx = 570
# Done
# idx = 571
# Done
# idx = 572
# Done
# idx = 573
# Done
# idx = 574
# Done
# idx = 575
# Done
# idx = 576
# Done
# idx = 577
# Done
# idx = 578
# Done
# idx = 579
# Done
# idx = 580
# Done
# idx = 581
# Done
# idx = 582
# Done
# idx = 583
# Done
# idx = 584
# Done
# idx = 585
# Done
# idx = 586
# Done
# idx = 587
# Done
# idx = 588
# Done
# idx = 589
# Done
# idx = 590
# Done
# idx = 591
# Done
# idx = 592
# Done
# idx = 593
# Done
# idx = 594
# Done
# idx = 595
# Done
# idx = 596
# Done
# idx = 597
# Done
# idx = 598
# Done
# idx = 599
# Done
# idx = 600
# Done
# idx = 601
# Done
# idx = 602
# Done
# idx = 603
# Done
# idx = 604
# Done
# idx = 605
# Done
# idx = 606
# Done
# idx = 607
# Done
# idx = 608
# Done
# idx = 609
# Done
# idx = 610
# Done
# idx = 611
# Done
# idx = 612
# Done
# idx = 613
# Done
# idx = 614
# Done
# idx = 615
# Done
# idx = 616
# Done
# idx = 617
# Done
# idx = 618
# Done
# idx = 619
# Done
# idx = 620
# Done
# idx = 621
# Done
# idx = 622
# Done
# idx = 623
# Done
# idx = 624
# Done
# idx = 625
# Done
# idx = 626
# Done
# idx = 627
# Done
# idx = 628
# Done
# idx = 629
# Done
# idx = 630
# Done
# idx = 631
# Done
# idx = 632
# Done
# idx = 633
# Done
# idx = 634
# Done
# idx = 635
# Done
# idx = 636
# Done
# idx = 637
# Done
# idx = 638
# Done
# idx = 639
# Done
# idx = 640
# Done
# idx = 641
# Done
# idx = 642
# Done
# idx = 643
# Done
# idx = 644
# Done
# idx = 645
# Done
# idx = 646
# Done
# idx = 647
# Done
# idx = 648
# Done
# idx = 649
# Done
# idx = 650
# Done
# idx = 651
# Done
# idx = 652
# Done
# idx = 653
# Done
# idx = 654
# Done
# idx = 655
# Done
# idx = 656
# Done
# idx = 657
# Done
# idx = 658
# Done
# idx = 659
# Done
# idx = 660
# Done
# idx = 661
# Done
# idx = 662
# Done
# idx = 663
# Done
# idx = 664
# Done
# idx = 665
# Done
# idx = 666
# Done
# idx = 667
# Done
# idx = 668
# Done
# idx = 669
# Done
# idx = 670
# Done
# idx = 671
# Done
# idx = 672
# Done
# idx = 673
# Done
# idx = 674
# Done
# idx = 675
# Done
# idx = 676
# Done
# idx = 677
# Done
# idx = 678
# ERROR1
# idx = 679
# Done
# idx = 680
# Done
# idx = 681
# Done
# idx = 682
# Done
# idx = 683
# Done
# idx = 684
# Done
# idx = 685
# Done
# idx = 686
# Done
# idx = 687
# Done
# idx = 688
# Done
# idx = 689
# Done
# idx = 690
# Done
# idx = 691
# Done
# idx = 692
# Done
# idx = 693
# Done
# idx = 694
# Done
# idx = 695
# Done
# idx = 696
# Done
# idx = 697
# Done
# idx = 698
# Done
# idx = 699
# Done
# idx = 700
# Done
# idx = 701
# Done
# idx = 702
# Done
# idx = 703
# Done
# idx = 704
# Done
# idx = 705
# Done
# idx = 706
# Done
# idx = 707
# Done
# idx = 708
# Done
# idx = 709
# Done
# idx = 710
# Done
# idx = 711
# Done
# idx = 712
# Done
# idx = 713
# Done
# idx = 714
# Done
# idx = 715
# Done
# idx = 716
# Done
# idx = 717
# Done
# idx = 718
# Done
# idx = 719
# Done
# idx = 720
# Done
# idx = 721
# Done
# idx = 722
# Done
# idx = 723
# Done
# idx = 724
# Done
# idx = 725
# Done
# idx = 726
# Done
# idx = 727
# Done
# idx = 728
# Done
# idx = 729
# Done
# idx = 730
# Done
# idx = 731
# Done
# idx = 732
# Done
# idx = 733
# Done
# idx = 734
# Done
# idx = 735
# Done
# idx = 736
# Done
# idx = 737
# Done
# idx = 738
# Done
# idx = 739
# Done
# idx = 740
# Done
# idx = 741
# Done
# idx = 742
# Done
# idx = 743
# Done
# idx = 744
# Done
# idx = 745
# Done
# idx = 746
# Done
# idx = 747
# Done
# idx = 748
# Done
# idx = 749
# Done
# idx = 750
# Done
# idx = 751
# Done
# idx = 752
# Done
# idx = 753
# Done
# idx = 754
# Done
# idx = 755
# Done
# idx = 756
# Done
# idx = 757
# Done
# idx = 758
# Done
# idx = 759
# Done
# idx = 760
# Done
# idx = 761
# Done
# idx = 762
# Done
# idx = 763
# Done
# idx = 764
# Done
# idx = 765
# Done
# idx = 766
# Done
# idx = 767
# Done
# idx = 768
# Done
# idx = 769
# Done
# idx = 770
# Done
# idx = 771
# Done
# idx = 772
# Done
# idx = 773
# Done
# idx = 774
# Done
# idx = 775
# Done
# idx = 776
# Done
# idx = 777
# Done
# idx = 778
# Done
# idx = 779
# Done
# idx = 780
# Done
# idx = 781
# Done
# idx = 782
# Done
# idx = 783
# TimeOut ERROR
# idx = 784
# Done
# idx = 785
# Done
# idx = 786
# Done
# idx = 787
# Done
# idx = 788
# Done
# idx = 789
# Done
# idx = 790
# Done
# idx = 791
# Done
# idx = 792
# Done
# idx = 793
# Done
# idx = 794
# Done
# idx = 795
# Done
# idx = 796
# Done
# idx = 797
# Done
# idx = 798
# Done
# idx = 799
# Done
# idx = 800
# Done
# idx = 801
# Done
# idx = 802
# Done
# idx = 803
# Done
# idx = 804
# Done
# idx = 805
# Done
# idx = 806
# Done
# idx = 807
# Done
# idx = 808
# Done
# idx = 809
# Done
# idx = 810
# Done
# idx = 811
# Done
# idx = 812
# Done
# idx = 813
# Done
# idx = 814
# Done
# idx = 815
# Done
# idx = 816
# Done
# idx = 817
# Done
# idx = 818
# Done
# idx = 819
# Done
# idx = 820
# Done
# idx = 821
# Done
# idx = 822
# Done
# idx = 823
# Done
# idx = 824
# Done
# idx = 825
# Done
# idx = 826
# Done
# idx = 827
# Done
# idx = 828
# Done
# idx = 829
# Done
# idx = 830
# Done
# idx = 831
# Done
# idx = 832
# Done
# idx = 833
# Done
# idx = 834
# Done
# idx = 835
# Done
# idx = 836
# Done
# idx = 837
# Done
# idx = 838
# Done
# idx = 839
# Done
# idx = 840
# Done
# idx = 841
# Done
# idx = 842
# Done
# idx = 843
# Done
# idx = 844
# Done
# idx = 845
# Done
# idx = 846
# Done
# idx = 847
# Done
# idx = 848
# Done
# idx = 849
# Done
# idx = 850
# Done
# idx = 851
# Done
# idx = 852
# Done
# idx = 853
# Done
# idx = 854
# Done
# idx = 855
# Done
# idx = 856
# Done
# idx = 857
# Done
# idx = 858
# Done
# idx = 859
# Done
# idx = 860
# Done
# idx = 861
# Done
# idx = 862
# Done
# idx = 863
# Done
# idx = 864
# Done
# idx = 865
# Done
# idx = 866
# Done
# idx = 867
# Done
# idx = 868
# Done
# idx = 869
# Done
# idx = 870
# Done
# idx = 871
# Done
# idx = 872
# Done
# idx = 873
# Done
# idx = 874
# Done
# idx = 875
# Done
# idx = 876
# Done
# idx = 877
# Done
# idx = 878
# Done
# idx = 879
# Done
# idx = 880
# Done
# idx = 881
# Done
# idx = 882
# Done
# idx = 883
# Done
# idx = 884
# Done
# idx = 885
# Done
# idx = 886
# Done
# idx = 887
# Done
# idx = 888
# Done
# idx = 889
# Done
# idx = 890
# Done
# idx = 891
# Done
# idx = 892
# Done
# idx = 893
# Done
# idx = 894
# Done
# idx = 895
# Done
# idx = 896
# Done
# idx = 897
# Done
# idx = 898
# Done
# idx = 899
# Done
# idx = 900
# Done
# idx = 901
# Done
# idx = 902
# Done
# idx = 903
# Done
# idx = 904
# Done
# idx = 905
# Done
# idx = 906
# Done
# idx = 907
# TimeOut ERROR
# idx = 908
# Done
# idx = 909
# Done
# idx = 910
# Done
# idx = 911
# Done
# idx = 912
# Done
# idx = 913
# Done
# idx = 914
# Done
# idx = 915
# Done
# idx = 916
# Done
# idx = 917
# Done
# idx = 918
# Done
# idx = 919
# Done
# idx = 920
# Done
# idx = 921
# Done
# idx = 922
# Done
# idx = 923
# Done
# idx = 924
# Done
# idx = 925
# Done
# idx = 926
# Done
# idx = 927
# Done
# idx = 928
# Done
# idx = 929
# Done
# idx = 930
# Done
# idx = 931
# Done
# idx = 932
# Done
# idx = 933
# Done
# idx = 934
# Done
# idx = 935
# Done
# idx = 936
# Done
# idx = 937
# Done
# idx = 938
# Done
# idx = 939
# Done
# idx = 940
# Done
# idx = 941
# Done
# idx = 942
# Done
# idx = 943
# Done
# idx = 944
# Done
# idx = 945
# Done
# idx = 946
# Done
# idx = 947
# Done
# idx = 948
# Done
# idx = 949
# Done
# idx = 950
# Done
# idx = 951
# Done
# idx = 952
# Done
# idx = 953
# Done
# idx = 954
# Done
# idx = 955
# Done
# idx = 956
# Done
# idx = 957
# Done
# idx = 958
# Done
# idx = 959
# Done
# idx = 960
# Done
# idx = 961
# Done
# idx = 962
# Done
# idx = 963
# Done
# idx = 964
# Done
# idx = 965
# Done
# idx = 966
# Done
# idx = 967
# Done
# idx = 968
# Done
# idx = 969
# Done
# idx = 970
# Done
# idx = 971
# Done
# idx = 972
# Done
# idx = 973
# Done
# idx = 974
# Done
# idx = 975
# Done
# idx = 976
# Done
# idx = 977
# Done
# idx = 978
# Done
# idx = 979
# Done
# idx = 980
# Done
# idx = 981
# Done
# idx = 982
# Done
# idx = 983
# Done
# idx = 984
# Done
# idx = 985
# Done
# idx = 986
# Done
# idx = 987
# Done
# idx = 988
# Done
# idx = 989
# Done
# idx = 990
# Done
# idx = 991
# Done
# idx = 992
# Done
# idx = 993
# Done
# idx = 994
# Done
# idx = 995
# Done
# idx = 996
# Done
# idx = 997
# Done
# idx = 998
# Done
# idx = 999
# Done
# idx = 1000
# Done
# idx = 1001
# Done
# idx = 1002
# Done
# idx = 1003
# Done
# idx = 1004
# Done
# idx = 1005
# Done
# idx = 1006
# Done
# idx = 1007
# Done
# idx = 1008
# Done
# idx = 1009
# Done
# idx = 1010
# Done
# idx = 1011
# Done
# idx = 1012
# Done
# idx = 1013
# Done
# idx = 1014
# Done
# idx = 1015
# Done
# idx = 1016
# Done
# idx = 1017
# Done
# idx = 1018
# Done
# idx = 1019
# Done
# idx = 1020
# Done
# idx = 1021
# Done
# idx = 1022
# Done
# idx = 1023
# Done
# idx = 1024
# Done
# idx = 1025
# Done
# idx = 1026
# Done
# idx = 1027
# Done
# idx = 1028
# Done
# idx = 1029
# Done
# idx = 1030
# Done
# idx = 1031
# ERROR1
# idx = 1032
# Done
# idx = 1033
# Done
# idx = 1034
# Done
# idx = 1035
# Done
# idx = 1036
# Done
# idx = 1037
# Done
# idx = 1038
# Done
# idx = 1039
# Done
# idx = 1040
# Done
# idx = 1041
# Done
# idx = 1042
# Done
# idx = 1043
# Done
# idx = 1044
# Done
# idx = 1045
# Done
# idx = 1046
# Done
# idx = 1047
# Done
# idx = 1048
# Done
# idx = 1049
# Done
# idx = 1050
# Done
# idx = 1051
# Done
# idx = 1052
# Done
# idx = 1053
# Done
# idx = 1054
# Done
# idx = 1055
# Done
# idx = 1056
# Done
# idx = 1057
# Done
# idx = 1058
# Done
# idx = 1059
# Done
# idx = 1060
# Done
# idx = 1061
# Done
# idx = 1062
# Done
# idx = 1063
# Done
# idx = 1064
# Done
# idx = 1065
# Done
# idx = 1066
# Done
# idx = 1067
# Done
# idx = 1068
# Done
# idx = 1069
# Done
# idx = 1070
# Done
# idx = 1071
# Done
# idx = 1072
# Done
# idx = 1073
# Done
# idx = 1074
# Done
# idx = 1075
# Done
# idx = 1076
# Done
# idx = 1077
# Done
# idx = 1078
# Done
# idx = 1079
# Done
# idx = 1080
# Done
# idx = 1081
# Done
# idx = 1082
# Done
# idx = 1083
# Done
# idx = 1084
# Done
# idx = 1085
# Done
# idx = 1086
# Done
# idx = 1087
# Done
# idx = 1088
# Done
# idx = 1089
# Done
# idx = 1090
# Done
# idx = 1091
# Done
# idx = 1092
# Done
# idx = 1093
# Done
# idx = 1094
# Done
# idx = 1095
# Done
# idx = 1096
# Done
# idx = 1097
# Done
# idx = 1098
# Done
# idx = 1099
# Done
# idx = 1100
# Done
# idx = 1101
# Done
# idx = 1102
# Done
# idx = 1103
# Done
# idx = 1104
# Done
# idx = 1105
# Done
# idx = 1106
# Done
# idx = 1107
# Done
# idx = 1108
# Done
# idx = 1109
# Done
# idx = 1110
# Done
# idx = 1111
# Done
# idx = 1112
# Done
# idx = 1113
# Done
# idx = 1114
# Done
# idx = 1115
# Done
# idx = 1116
# Done
# idx = 1117
# Done
# idx = 1118
# Done
# idx = 1119
# Done
# idx = 1120
# Done
# idx = 1121
# Done
# idx = 1122
# Done
# idx = 1123
# Done
# idx = 1124
# Done
# idx = 1125
# Done
# idx = 1126
# Done
# idx = 1127
# Done
# idx = 1128
# Done
# idx = 1129
# Done
# idx = 1130
# Done
# idx = 1131
# Done
# idx = 1132
# Done
# idx = 1133
# Done
# idx = 1134
# Done
# idx = 1135
# Done
# idx = 1136
# Done
# idx = 1137
# Done
# idx = 1138
# Done
# idx = 1139
# Done
# idx = 1140
# Done
# idx = 1141
# Done
# idx = 1142
# Done
# idx = 1143
# Done
# idx = 1144
# Done
# idx = 1145
# Done
# idx = 1146
# Done
# idx = 1147
# Done
# idx = 1148
# Done
# idx = 1149
# Done
# idx = 1150
# Done
# idx = 1151
# Done
# idx = 1152
# Done
# idx = 1153
# Done
# idx = 1154
# Done
# idx = 1155
# Done
# idx = 1156
# Done
# idx = 1157
# Done
# idx = 1158
# Done
# idx = 1159
# Done
# idx = 1160
# Done
# idx = 1161
# Done
# idx = 1162
# Done
# idx = 1163
# Done
# idx = 1164
# Done
# idx = 1165
# Done
# idx = 1166
# Done
# idx = 1167
# Done
# idx = 1168
# Done
# idx = 1169
# Done
# idx = 1170
# Done
# idx = 1171
# Done
# idx = 1172
# Done
# idx = 1173
# Done
# idx = 1174
# Done
# idx = 1175
# Done
# idx = 1176
# Done
# idx = 1177
# Done
# idx = 1178
# Done
# idx = 1179
# Done
# idx = 1180
# Done
# idx = 1181
# Done
# idx = 1182
# Done
# idx = 1183
# Done
# idx = 1184
# Done
# idx = 1185
# Done
# idx = 1186
# Done
# idx = 1187
# Done
# idx = 1188
# Done
# idx = 1189
# Done
# idx = 1190
# Done
# idx = 1191
# Done
# idx = 1192
# Done
# idx = 1193
# Done
# idx = 1194
# Done
# idx = 1195
# Done
# idx = 1196
# Done
# idx = 1197
# Done
# idx = 1198
# Done
# idx = 1199
# Done
# idx = 1200
# Done
# idx = 1201
# Done
# idx = 1202
# Done
# idx = 1203
# Done
# idx = 1204
# Done
# idx = 1205
# Done
# idx = 1206
# Done
# idx = 1207
# Done
# idx = 1208
# Done
# idx = 1209
# Done
# idx = 1210
# Done
# idx = 1211
# Done
# idx = 1212
# Done
# idx = 1213
# Done
# idx = 1214
# Done
# idx = 1215
# Done
# idx = 1216
# Done
# idx = 1217
# Done
# idx = 1218
# Done
# idx = 1219
# Done
# idx = 1220
# Done
# idx = 1221
# Done
# idx = 1222
# Done
# idx = 1223
# Done
# idx = 1224
# Done
# idx = 1225
# Done
# idx = 1226
# Done
# idx = 1227
# Done
# idx = 1228
# Done
# idx = 1229
# Done
# idx = 1230
# Done
# idx = 1231
# Done
# idx = 1232
# Done
# idx = 1233
# Done
# idx = 1234
# Done
# idx = 1235
# Done
# idx = 1236
# Done
# idx = 1237
# Done
# idx = 1238
# Done
# idx = 1239
# Done
# idx = 1240
# Done
# idx = 1241
# Done
# idx = 1242
# Done
# idx = 1243
# Done
# idx = 1244
# Done
# idx = 1245
# Done
# idx = 1246
# Done
# idx = 1247
# Done
# idx = 1248
# Done
# idx = 1249
# Done
# idx = 1250
# Done
# idx = 1251
# Done
# idx = 1252
# Done
# idx = 1253
# Done
# idx = 1254
# Done
# idx = 1255
# Done
# idx = 1256
# Done
# idx = 1257
# Done
# idx = 1258
# Done
# idx = 1259
# Done
# idx = 1260
# Done
# idx = 1261
# Done
# idx = 1262
# Done
# idx = 1263
# Done
# idx = 1264
# Done
# idx = 1265
# Done
# idx = 1266
# Done
# idx = 1267
# Done
# idx = 1268
# Done
# idx = 1269
# Done
# idx = 1270
# Done
# idx = 1271
# Done
# idx = 1272
# Done
# idx = 1273
# Done
# idx = 1274
# Done
# idx = 1275
# Done
# idx = 1276
# Done
# idx = 1277
# Done
# idx = 1278
# Done
# idx = 1279
# Done
# idx = 1280
# Done
# idx = 1281
# Done
# idx = 1282
# Done
# idx = 1283
# Done
# idx = 1284
# Done
# idx = 1285
# Done
# idx = 1286
# Done
# idx = 1287
# Done
# idx = 1288
# Done
# idx = 1289
# Done
# idx = 1290
# Done
# idx = 1291
# Done
# idx = 1292
# Done
# idx = 1293
# Done
# idx = 1294
# Done
# idx = 1295
# Done
# idx = 1296
# Done
# idx = 1297
# Done
# idx = 1298
# Done
# idx = 1299
# Done
# idx = 1300
# Done
# idx = 1301
# Done
# idx = 1302
# Done
# idx = 1303
# Done
# idx = 1304
# Done
# idx = 1305
# Done
# idx = 1306
# Done
# idx = 1307
# Done
# idx = 1308
# Done
# idx = 1309
# TimeOut ERROR
# idx = 1310
# Done
# idx = 1311
# Done
# idx = 1312
# Done
# idx = 1313
# Done
# idx = 1314
# Done
# idx = 1315
# Done
# idx = 1316
# Done
# idx = 1317
# Done
# idx = 1318
# Done
# idx = 1319
# Done
# idx = 1320
# Done
# idx = 1321
# Done
# idx = 1322
# Done
# idx = 1323
# Done
# idx = 1324
# Done
# idx = 1325
# Done
# idx = 1326
# Done
# idx = 1327
# Done
# idx = 1328
# Done
# idx = 1329
# Done
# idx = 1330
# Done
# idx = 1331
# Done
# idx = 1332
# Done
# idx = 1333
# Done
# idx = 1334
# Done
# idx = 1335
# Done
# idx = 1336
# Done
# idx = 1337
# Done
# idx = 1338
# Done
# idx = 1339
# Done
# idx = 1340
# Done
# idx = 1341
# Done
# idx = 1342
# Done
# idx = 1343
# Done
# idx = 1344
# Done
# idx = 1345
# Done
# idx = 1346
# Done
# idx = 1347
# Done
# idx = 1348
# Done
# idx = 1349
# Done
# idx = 1350
# Done
# idx = 1351
# Done
# idx = 1352
# Done
# idx = 1353
# Done
# idx = 1354
# Done
# idx = 1355
# Done
# idx = 1356
# Done
# idx = 1357
# Done
# idx = 1358
# Done
# idx = 1359
# Done
# idx = 1360
# Done
# idx = 1361
# Done
# idx = 1362
# Done
# idx = 1363
# Done
# idx = 1364
# Done
# idx = 1365
# Done
# idx = 1366
# Done
# idx = 1367
# Done
# idx = 1368
# Done
# idx = 1369
# Done
# idx = 1370
# Done
# idx = 1371
# Done
# idx = 1372
# Done
# idx = 1373
# Done
# idx = 1374
# Done
# idx = 1375
# Done
# idx = 1376
# Done
# idx = 1377
# Done
# idx = 1378
# Done
# idx = 1379
# Done
# idx = 1380
# Done
# idx = 1381
# Done
# idx = 1382
# Done
# idx = 1383
# Done
# idx = 1384
# Done
# idx = 1385
# Done
# idx = 1386
# Done
# idx = 1387
# Done
# idx = 1388
# Done
# idx = 1389
# Done
# idx = 1390
# Done
# idx = 1391
# Done
# idx = 1392
# Done
# idx = 1393
# Done
# idx = 1394
# Done
# idx = 1395
# Done
# idx = 1396
# Done
# idx = 1397
# Done
# idx = 1398
# Done
# idx = 1399
# Done
# idx = 1400
# Done
# idx = 1401
# Done
# idx = 1402
# Done
# idx = 1403
# Done
# idx = 1404
# Done
# idx = 1405
# Done
# idx = 1406
# Done
# idx = 1407
# Done
# idx = 1408
# Done
# idx = 1409
# Done
# idx = 1410
# Done
# idx = 1411
# Done
# idx = 1412
# Done
# idx = 1413
# Done
# idx = 1414
# Done
# idx = 1415
# Done
# idx = 1416
# Done
# idx = 1417
# Done
# idx = 1418
# Done
# idx = 1419
# Done
# idx = 1420
# Done
# idx = 1421
# Done
# idx = 1422
# Done
# idx = 1423
# Done
# idx = 1424
# Done
# idx = 1425
# Done
# idx = 1426
# Done
# idx = 1427
# Done
# idx = 1428
# Done
# idx = 1429
# Done
# idx = 1430
# Done
# idx = 1431
# Done
# idx = 1432
# Done
# idx = 1433
# Done
# idx = 1434
# Done
# idx = 1435
# Done
# idx = 1436
# Done
# idx = 1437
# Done
# idx = 1438
# Done
# idx = 1439
# Done
# idx = 1440
# Done
# idx = 1441
# Done
# idx = 1442
# Done
# idx = 1443
# Done
# idx = 1444
# Done
# idx = 1445
# Done
# idx = 1446
# Done
# idx = 1447
# Done
# idx = 1448
# Done
# idx = 1449
# Done
# idx = 1450
# Done
# idx = 1451
# Done
# idx = 1452
# Done
# idx = 1453
# Done
# idx = 1454
# Done
# idx = 1455
# Done
# idx = 1456
# Done
# idx = 1457
# Done
# idx = 1458
# Done
# idx = 1459
# Done
# idx = 1460
# Done
# idx = 1461
# Done
# idx = 1462
# Done
# idx = 1463
# Done
# idx = 1464
# Done
# idx = 1465
# Done
# idx = 1466
# Done
# idx = 1467
# Done
# idx = 1468
# Done
# idx = 1469
# Done
# idx = 1470
# Done
# idx = 1471
# Done
# idx = 1472
# Done
# idx = 1473
# Done
# idx = 1474
# Done
# idx = 1475
# Done
# idx = 1476
# Done
# idx = 1477
# Done
# idx = 1478
# Done
# idx = 1479
# Done
# idx = 1480
# Done
# idx = 1481
# Done
# idx = 1482
# Done
# idx = 1483
# Done
# idx = 1484
# Done
# idx = 1485
# Done
# idx = 1486
# Done
# idx = 1487
# Done
# idx = 1488
# Done
# idx = 1489
# Done
# idx = 1490
# Done
# idx = 1491
# Done
# idx = 1492
# Done
# idx = 1493
# Done
# idx = 1494
# Done
# idx = 1495
# Done
# idx = 1496
# Done
# idx = 1497
# Done
# idx = 1498
# Done
# idx = 1499
# Done
# idx = 1500
# Done
# idx = 1501
# Done
# idx = 1502
# Done
# idx = 1503
# Done
# idx = 1504
# Done
# idx = 1505
# Done
# idx = 1506
# Done
# idx = 1507
# Done
# idx = 1508
# Done
# idx = 1509
# Done
# idx = 1510
# Done
# idx = 1511
# Done
# idx = 1512
# Done
# idx = 1513
# Done
# idx = 1514
# Done
# idx = 1515
# Done
# idx = 1516
# Done
# idx = 1517
# Done
# idx = 1518
# Done
# idx = 1519
# Done
# idx = 1520
# Done
# idx = 1521
# Done
# idx = 1522
# Done
# idx = 1523
# Done
# idx = 1524
# Done
# idx = 1525
# Done
# idx = 1526
# Done
# idx = 1527
# Done
# idx = 1528
# Done
# idx = 1529
# Done
# idx = 1530
# Done
# idx = 1531
# Done
# idx = 1532
# Done
# idx = 1533
# Done
# idx = 1534
# Done
# idx = 1535
# Done
# idx = 1536
# Done
# idx = 1537
# Done
# idx = 1538
# Done
# idx = 1539
# Done
# idx = 1540
# Done
# idx = 1541
# Done
# idx = 1542
# Done
# idx = 1543
# Done
# idx = 1544
# Done
# idx = 1545
# Done
# idx = 1546
# Done
# idx = 1547
# Done
# idx = 1548
# Done
# idx = 1549
# Done
# idx = 1550
# Done
# idx = 1551
# Done
# idx = 1552
# Done
# idx = 1553
# Done
# idx = 1554
# Done
# idx = 1555
# Done
# idx = 1556
# Done
# idx = 1557
# Done
# idx = 1558
# Done
# idx = 1559
# Done
# idx = 1560
# Done
# idx = 1561
# Done
# idx = 1562
# Done
# idx = 1563
# Done
# idx = 1564
# Done
# idx = 1565
# Done
# idx = 1566
# Done
# idx = 1567
# Done
# idx = 1568
# Done
# idx = 1569
# Done
# idx = 1570
# Done
# idx = 1571
# Done
# idx = 1572
# Done
# idx = 1573
# Done
# idx = 1574
# Done
# idx = 1575
# Done
# idx = 1576
# Done
# idx = 1577
# Done
# idx = 1578
# Done
# idx = 1579
# Done
# idx = 1580
# Done
# idx = 1581
# Done
# idx = 1582
# Done
# idx = 1583
# Done
# idx = 1584
# Done
# idx = 1585
# Done
# idx = 1586
# Done
# idx = 1587
# Done
# idx = 1588
# Done
# idx = 1589
# Done
# idx = 1590
# Done
# idx = 1591
# Done
# idx = 1592
# Done
# idx = 1593
# Done
# idx = 1594
# Done
# idx = 1595
# Done
# idx = 1596
# Done
# idx = 1597
# Done
# idx = 1598
# Done
# idx = 1599
# Done
# idx = 1600
# Done
# idx = 1601
# Done
# idx = 1602
# Done
# idx = 1603
# Done
# idx = 1604
# Done
# idx = 1605
# Done
# idx = 1606
# Done
# idx = 1607
# Done
# idx = 1608
# Done
# idx = 1609
# Done
# idx = 1610
# Done
# idx = 1611
# Done
# idx = 1612
# Done
# idx = 1613
# Done
# idx = 1614
# Done
# idx = 1615
# Done
# idx = 1616
# Done
# idx = 1617
# Done
# idx = 1618
# Done
# idx = 1619
# Done
# idx = 1620
# Done
# idx = 1621
# Done
# idx = 1622
# Done
# idx = 1623
# Done
# idx = 1624
# Done
# idx = 1625
# Done
# idx = 1626
# Done
# idx = 1627
# Done
# idx = 1628
# Done
# idx = 1629
# Done
# idx = 1630
# Done
# idx = 1631
# Done
# idx = 1632
# Done
# idx = 1633
# Done
# idx = 1634
# Done
# idx = 1635
# Done
# idx = 1636
# Done
# idx = 1637
# Done
# idx = 1638
# Done
# idx = 1639
# Done
# idx = 1640
# Done
# idx = 1641
# Done
# idx = 1642
# Done
# idx = 1643
# Done
# idx = 1644
# Done
# idx = 1645
# Done
# idx = 1646
# Done
# idx = 1647
# Done
# idx = 1648
# Done
# idx = 1649
# Done
# idx = 1650
# Done
# idx = 1651
# Done
# idx = 1652
# Done
# idx = 1653
# Done
# idx = 1654
# Done
# idx = 1655
# Done
# idx = 1656
# Done
# idx = 1657
# Done
# idx = 1658
# Done
# idx = 1659
# Done
# idx = 1660
# Done
# idx = 1661
# Done
# idx = 1662
# Done
# idx = 1663
# Done
# idx = 1664
# Done
# idx = 1665
# Done
# idx = 1666
# Done
# idx = 1667
# Done
# idx = 1668
# Done
# idx = 1669
# Done
# idx = 1670
# Done
# idx = 1671
# Done
# idx = 1672
# Done
# idx = 1673
# Done
# idx = 1674
# Done
# idx = 1675
# Done
# idx = 1676
# Done
# idx = 1677
# Done
# idx = 1678
# Done
# idx = 1679
# Done
# idx = 1680
# Done
# idx = 1681
# Done
# idx = 1682
# Done
# idx = 1683
# Done
# idx = 1684
# Done
# idx = 1685
# Done
# idx = 1686
# Done
# idx = 1687
# Done
# idx = 1688
# Done
# idx = 1689
# Done
# idx = 1690
# Done
# idx = 1691
# Done
# idx = 1692
# Done
# idx = 1693
# Done
# idx = 1694
# Done
# idx = 1695
# Done
# idx = 1696
# Done
# idx = 1697
# Done
# idx = 1698
# Done
# idx = 1699
# Done
# idx = 1700
# Done
# idx = 1701
# Done
# idx = 1702
# Done
# idx = 1703
# Done
# idx = 1704
# Done
# idx = 1705
# Done
# idx = 1706
# Done
# idx = 1707
# Done
# idx = 1708
# Done
# idx = 1709
# Done
# idx = 1710
# Done
# idx = 1711
# Done
# idx = 1712
# Done
# idx = 1713
# Done
# idx = 1714
# Done
# idx = 1715
# Done
# idx = 1716
# Done
# idx = 1717
# Done
# idx = 1718
# Done
# idx = 1719
# Done
# idx = 1720
# Done
# idx = 1721
# Done
# idx = 1722
# Done
# idx = 1723
# Done
# idx = 1724
# Done
# idx = 1725
# Done
# idx = 1726
# Done
# idx = 1727
# Done
# idx = 1728
# Done
# idx = 1729
# Done
# idx = 1730
# Done
# idx = 1731
# Done
# idx = 1732
# Done
# idx = 1733
# Done
# idx = 1734
# Done
# idx = 1735
# Done
# idx = 1736
# Done
# idx = 1737
# Done
# idx = 1738
# Done
# idx = 1739
# Done
# idx = 1740
# Done
# idx = 1741
# Done
# idx = 1742
# Done
# idx = 1743
# Done
# idx = 1744
# Done
# idx = 1745
# Done
# idx = 1746
# Done
# idx = 1747
# Done
# idx = 1748
# Done
# idx = 1749
# Done
# idx = 1750
# Done
# idx = 1751
# Done
# idx = 1752
# Done
# idx = 1753
# Done
# idx = 1754
# Done
# idx = 1755
# Done
# idx = 1756
# Done
# idx = 1757
# Done
# idx = 1758
# Done
# idx = 1759
# Done
# idx = 1760
# Done
# idx = 1761
# Done
# idx = 1762
# Done
# idx = 1763
# Done
# idx = 1764
# Done
# idx = 1765
# Done
# idx = 1766
# Done
# idx = 1767
# Done
# idx = 1768
# Done
# idx = 1769
# Done
# idx = 1770
# Done
# idx = 1771
# Done
# idx = 1772
# Done
# idx = 1773
# Done
# idx = 1774
# Done
# idx = 1775
# Done
# idx = 1776
# Done
# idx = 1777
# Done
# idx = 1778
# Done
# idx = 1779
# Done
# idx = 1780
# Done
# idx = 1781
# Done
# idx = 1782
# Done
# idx = 1783
# Done
# idx = 1784
# Done
# idx = 1785
# Done
# idx = 1786
# Done
# idx = 1787
# Done
# idx = 1788
# Done
# idx = 1789
# Done
# idx = 1790
# Done
# idx = 1791
# Done
# idx = 1792
# Done
# idx = 1793
# Done
# idx = 1794
# Done
# idx = 1795
# Done
# idx = 1796
# Done
# idx = 1797
# Done
# idx = 1798
# Done
# idx = 1799
# Done
# idx = 1800
# Done
# idx = 1801
# Done
# idx = 1802
# Done
# idx = 1803
# Done
# idx = 1804
# Done
# idx = 1805
# Done
# idx = 1806
# Done
# idx = 1807
# Done
# idx = 1808
# Done
# idx = 1809
# Done
# idx = 1810
# Done
# idx = 1811
# Done
# idx = 1812
# Done
# idx = 1813
# Done
# idx = 1814
# Done
# idx = 1815
# Done
# idx = 1816
# Done
# idx = 1817
# Done
# idx = 1818
# Done
# idx = 1819
# Done
# idx = 1820
# Done
# idx = 1821
# Done
# idx = 1822
# Done
# idx = 1823
# Done
# idx = 1824
# Done
# idx = 1825
# Done
# idx = 1826
# Done
# idx = 1827
# Done
# idx = 1828
# Done
# idx = 1829
# Done
# idx = 1830
# Done
# idx = 1831
# Done
# idx = 1832
# Done
# idx = 1833
# Done
# idx = 1834
# Done
# idx = 1835
# Done
# idx = 1836
# Done
# idx = 1837
# Done
# idx = 1838
# Done
# idx = 1839
# Done
# idx = 1840
# Done
# idx = 1841
# Done
# idx = 1842
# Done
# idx = 1843
# Done
# idx = 1844
# Done
# idx = 1845
# Done
# idx = 1846
# Done
# idx = 1847
# Done
# idx = 1848
# Done
# idx = 1849
# Done
# idx = 1850
# Done
# idx = 1851
# Done
# idx = 1852
# Done
# idx = 1853
# Done
# idx = 1854
# Done
# idx = 1855
# Done
# idx = 1856
# Done
# idx = 1857
# Done
# idx = 1858
# Done
# idx = 1859
# Done
# idx = 1860
# Done
# idx = 1861
# Done
# idx = 1862
# Done
# idx = 1863
# Done
# idx = 1864
# Done
# idx = 1865
# Done
# idx = 1866
# Done
# idx = 1867
# Done
# idx = 1868
# Done
# idx = 1869
# Done
# idx = 1870
# Done
# idx = 1871
# Done
# idx = 1872
# Done
# idx = 1873
# Done
# idx = 1874
# Done
# idx = 1875
# Done
# idx = 1876
# Done
# idx = 1877
# Done
# idx = 1878
# Done
# idx = 1879
# Done
# idx = 1880
# Done
# idx = 1881
# Done
# idx = 1882
# Done
# idx = 1883
# Done
# idx = 1884
# Done
# idx = 1885
# Done
# idx = 1886
# Done
# idx = 1887
# Done
# idx = 1888
# Done
# idx = 1889
# Done
# idx = 1890
# Done
# idx = 1891
# Done
# idx = 1892
# Done
# idx = 1893
# Done
# idx = 1894
# Done
# idx = 1895
# Done
# idx = 1896
# Done
# idx = 1897
# Done
# idx = 1898
# Done
# idx = 1899
# Done
# idx = 1900
# Done
# idx = 1901
# Done
# idx = 1902
# Done
# idx = 1903
# Done
# idx = 1904
# Done
# idx = 1905
# Done
# idx = 1906
# Done
# idx = 1907
# Done
# idx = 1908
# Done
# idx = 1909
# Done
# idx = 1910
# Done
# idx = 1911
# Done
# idx = 1912
# Done
# idx = 1913
# Done
# idx = 1914
# Done
# idx = 1915
# Done
# idx = 1916
# Done
# idx = 1917
# Done
# idx = 1918
# Done
# idx = 1919
# Done
# idx = 1920
# Done
# idx = 1921
# Done
# idx = 1922
# Done
# idx = 1923
# Done
# idx = 1924
# Done
# idx = 1925
# Done
# idx = 1926
# Done
# idx = 1927
# Done
# idx = 1928
# Done
# idx = 1929
# Done
# idx = 1930
# Done
# idx = 1931
# Done
# idx = 1932
# Done
# idx = 1933
# Done
# idx = 1934
# Done
# idx = 1935
# Done
# idx = 1936
# Done
# idx = 1937
# Done
# idx = 1938
# Done
# idx = 1939
# Done
# idx = 1940
# Done
# idx = 1941
# Done
# idx = 1942
# Done
# idx = 1943
# Done
# idx = 1944
# Done
# idx = 1945
# Done
# idx = 1946
# Done
# idx = 1947
# Done
# idx = 1948
# Done
# idx = 1949
# Done
# idx = 1950
# Done
# idx = 1951
# Done
# idx = 1952
# Done
# idx = 1953
# Done
# idx = 1954
# Done
# idx = 1955
# Done
# idx = 1956
# Done
# idx = 1957
# Done
# idx = 1958
# Done
# idx = 1959
# Done
# idx = 1960
# Done
# idx = 1961
# Done
# idx = 1962
# Done
# idx = 1963
# Done
# idx = 1964
# Done
# idx = 1965
# Done
# idx = 1966
# Done
# idx = 1967
# Done
# idx = 1968
# Done
# idx = 1969
# Done
# idx = 1970
# Done
# idx = 1971
# Done
# idx = 1972
# Done
# idx = 1973
# Done
# idx = 1974
# Done
# idx = 1975
# Done
# idx = 1976
# Done
# idx = 1977
# Done
# idx = 1978
# Done
# idx = 1979
# Done
# idx = 1980
# Done
# idx = 1981
# Done
# idx = 1982
# Done
# idx = 1983
# Done
# idx = 1984
# Done
# idx = 1985
# Done
# idx = 1986
# Done
# idx = 1987
# Done
# idx = 1988
# Done
# idx = 1989
# Done
# idx = 1990
# Done
# idx = 1991
# Done
# idx = 1992
# Done
# idx = 1993
# Done
# idx = 1994
# Done
# idx = 1995
# Done
# idx = 1996
# Done
# idx = 1997
# Done
# idx = 1998
# Done
# idx = 1999
# Done
# idx = 2000
# Done
# idx = 2001
# Done
# idx = 2002
# Done
# idx = 2003
# Done
# idx = 2004
# Done
# idx = 2005
# Done
# idx = 2006
# Done
# idx = 2007
# Done
# idx = 2008
# Done
# idx = 2009
# Done
# idx = 2010
# Done
# idx = 2011
# Done
# idx = 2012
# Done
# idx = 2013
# Done
# idx = 2014
# Done
# idx = 2015
# Done
# idx = 2016
# Done
# idx = 2017
# Done
# idx = 2018
# Done
# idx = 2019
# Done
# idx = 2020
# Done
# idx = 2021
# Done
# idx = 2022
# Done
# idx = 2023
# Done
# idx = 2024
# Done
# idx = 2025
# Done
# idx = 2026
# Done
# idx = 2027
# Done
# idx = 2028
# Done
# idx = 2029
# Done
# idx = 2030
# Done
# idx = 2031
# Done
# idx = 2032
# Done
# idx = 2033
# Done
# idx = 2034
# Done
# idx = 2035
# Done
# idx = 2036
# Done
# idx = 2037
# Done
# idx = 2038
# Done
# idx = 2039
# Done
# idx = 2040
# Done
# idx = 2041
# Done
# idx = 2042
# Done
# idx = 2043
# Done
# idx = 2044
# Done
# idx = 2045
# Done
# idx = 2046
# Done
# idx = 2047
# Done
# idx = 2048
# Done
# idx = 2049
# Done
# idx = 2050
# Done
# idx = 2051
# Done
# idx = 2052
# Done
# idx = 2053
# Done
# idx = 2054
# Done
# idx = 2055
# Done
# idx = 2056
# Done
# idx = 2057
# Done
# idx = 2058
# Done
# idx = 2059
# Done
# idx = 2060
# Done
# idx = 2061
# Done
# idx = 2062
# Done
# idx = 2063
# Done
# idx = 2064
# Done
# idx = 2065
# Done
# idx = 2066
# Done
# idx = 2067
# Done
# idx = 2068
# Done
# idx = 2069
# Done
# idx = 2070
# Done
# idx = 2071
# Done
# idx = 2072
# Done
# idx = 2073
# Done
# idx = 2074
# Done
# idx = 2075
# Done
# idx = 2076
# Done
# idx = 2077
# Done
# idx = 2078
# Done
# idx = 2079
# Done
# idx = 2080
# Done
# idx = 2081
# Done
# idx = 2082
# Done
# idx = 2083
# Done
# idx = 2084
# Done
# idx = 2085
# Done
# idx = 2086
# Done
# idx = 2087
# Done
# idx = 2088
# Done
# idx = 2089
# Done
# idx = 2090
# Done
# idx = 2091
# Done
# idx = 2092
# Done
# idx = 2093
# Done
# idx = 2094
# Done
# idx = 2095
# Done
# idx = 2096
# Done
# idx = 2097
# Done
# idx = 2098
# Done
# idx = 2099
# Done
# idx = 2100
# Done
# idx = 2101
# Done
# idx = 2102
# Done
# idx = 2103
# Done
# idx = 2104
# Done
# idx = 2105
# Done
# idx = 2106
# Done
# idx = 2107
# Done
# idx = 2108
# Done
# idx = 2109
# Done
# idx = 2110
# Done
# idx = 2111
# Done
# idx = 2112
# Done
# idx = 2113
# Done
# idx = 2114
# Done
# idx = 2115
# Done
# idx = 2116
# Done
# idx = 2117
# Done
# idx = 2118
# Done
# idx = 2119
# Done
# idx = 2120
# Done
# idx = 2121
# Done
# idx = 2122
# Done
# idx = 2123
# Done
# idx = 2124
# Done
# idx = 2125
# Done
# idx = 2126
# Done
# idx = 2127
# Done
# idx = 2128
# Done
# idx = 2129
# Done
# idx = 2130
# Done
# idx = 2131
# Done
# idx = 2132
# Done
# idx = 2133
# Done
# idx = 2134
# Done
# idx = 2135
# Done
# idx = 2136
# Done
# idx = 2137
# Done
# idx = 2138
# Done
# idx = 2139
# Done
# idx = 2140
# Done
# idx = 2141
# Done
# idx = 2142
# Done
# idx = 2143
# Done
# idx = 2144
# Done
# idx = 2145
# Done
# idx = 2146
# Done
# idx = 2147
# Done
# idx = 2148
# Done
# idx = 2149
# Done
# idx = 2150
# Done
# idx = 2151
# Done
# idx = 2152
# Done
# idx = 2153
# Done
# idx = 2154
# Done
# idx = 2155
# Done
# idx = 2156
# Done
# idx = 2157
# Done
# idx = 2158
# Done
# idx = 2159
# Done
# idx = 2160
# Done
# idx = 2161
# Done
# idx = 2162
# Done
# idx = 2163
# Done
# idx = 2164
# Done
# idx = 2165
# Done
# idx = 2166
# Done
# idx = 2167
# Done
# idx = 2168
# Done
# idx = 2169
# Done
# idx = 2170
# Done
# idx = 2171
# Done
# idx = 2172
# Done
# idx = 2173
# Done
# idx = 2174
# Done
# idx = 2175
# Done
# idx = 2176
# Done
# idx = 2177
# Done
# idx = 2178
# Done
# idx = 2179
# Done
# idx = 2180
# Done
# idx = 2181
# Done
# idx = 2182
# Done
# idx = 2183
# Done
# idx = 2184
# ERROR1
# idx = 2185
# Done
# idx = 2186
# Done
# idx = 2187
# Done
# idx = 2188
# Done
# idx = 2189
# Done
# idx = 2190
# Done
# idx = 2191
# Done
# idx = 2192
# Done
# idx = 2193
# Done
# idx = 2194
# Done
# idx = 2195
# Done
# idx = 2196
# Done
# idx = 2197
# Done
# idx = 2198
# Done
# idx = 2199
# Done
# idx = 2200
# Done
# idx = 2201
# Done
# idx = 2202
# Done
# idx = 2203
# Done
# idx = 2204
# Done
# idx = 2205
# Done
# idx = 2206
# Done
# idx = 2207
# Done
# idx = 2208
# Done
# idx = 2209
# Done
# idx = 2210
# Done
# idx = 2211
# Done
# idx = 2212
# Done
# idx = 2213
# Done
# idx = 2214
# Done
# idx = 2215
# Done
# idx = 2216
# Done
# idx = 2217
# Done
# idx = 2218
# Done
# idx = 2219
# Done
# idx = 2220
# Done
# idx = 2221
# Done
# idx = 2222
# Done
# idx = 2223
# Done
# idx = 2224
# Done
# idx = 2225
# Done
# idx = 2226
# Done
# idx = 2227
# Done
# idx = 2228
# Done
# idx = 2229
# Done
# idx = 2230
# Done
# idx = 2231
# Done
# idx = 2232
# Done
# idx = 2233
# Done
# idx = 2234
# Done
# idx = 2235
# Done
# idx = 2236
# Done
# idx = 2237
# Done
# idx = 2238
# Done
# idx = 2239
# Done
# idx = 2240
# Done
# idx = 2241
# Done
# idx = 2242
# Done
# idx = 2243
# Done
# idx = 2244
# Done
# idx = 2245
# Done
# idx = 2246
# Done
# idx = 2247
# Done
# idx = 2248
# Done
# idx = 2249
# Done
# idx = 2250
# Done
# idx = 2251
# Done
# idx = 2252
# Done
# idx = 2253
# Done
# idx = 2254
# Done
# idx = 2255
# Done
# idx = 2256
# Done
# idx = 2257
# Done
# idx = 2258
# Done
# idx = 2259
# Done
# idx = 2260
# Done
# idx = 2261
# Done
# idx = 2262
# Done
# idx = 2263
# Done
# idx = 2264
# Done
# idx = 2265
# Done
# idx = 2266
# Done
# idx = 2267
# Done
# idx = 2268
# Done
# idx = 2269
# Done
# idx = 2270
# Done
# idx = 2271
# Done
# idx = 2272
# Done
# idx = 2273
# Done
# idx = 2274
# Done
# idx = 2275
# Done
# idx = 2276
# Done
# idx = 2277
# Done
# idx = 2278
# Done
# idx = 2279
# Done
# idx = 2280
# Done
# idx = 2281
# Done
# idx = 2282
# Done
# idx = 2283
# Done
# idx = 2284
# Done
# idx = 2285
# Done
# idx = 2286
# Done
# idx = 2287
# Done
# idx = 2288
# Done
# idx = 2289
# Done
# idx = 2290
# Done
# idx = 2291
# Done
# idx = 2292
# Done
# idx = 2293
# Done
# idx = 2294
# Done
# idx = 2295
# Done
# idx = 2296
# Done
# idx = 2297
# Done
# idx = 2298
# Done
# idx = 2299
# Done
# idx = 2300
# Done
# idx = 2301
# Done
# idx = 2302
# Done
# idx = 2303
# Done
# idx = 2304
# Done
# idx = 2305
# Done
# idx = 2306
# Done
# idx = 2307
# Done
# idx = 2308
# Done
# idx = 2309
# Done
# idx = 2310
# Done
# idx = 2311
# Done
# idx = 2312
# Done
# idx = 2313
# Done
# idx = 2314
# Done
# idx = 2315
# Done
# idx = 2316
# Done
# idx = 2317
# Done
# idx = 2318
# Done
# idx = 2319
# Done
# idx = 2320
# Done
# idx = 2321
# Done
# idx = 2322
# Done
# idx = 2323
# Done
# idx = 2324
# Done
# idx = 2325
# Done
# idx = 2326
# Done
# idx = 2327
# Done
# idx = 2328
# Done
# idx = 2329
# Done
# idx = 2330
# Done
# idx = 2331
# Done
# idx = 2332
# Done
# idx = 2333
# Done
# idx = 2334
# Done
# idx = 2335
# Done
# idx = 2336
# Done
# idx = 2337
# Done
# idx = 2338
# Done
# idx = 2339
# Done
# idx = 2340
# Done
# idx = 2341
# Done
# idx = 2342
# Done
# idx = 2343
# Done
# idx = 2344
# Done
# idx = 2345
# Done
# idx = 2346
# Done
# idx = 2347
# Done
# idx = 2348
# Done
# idx = 2349
# Done
# idx = 2350
# Done
# idx = 2351
# Done
# idx = 2352
# Done
# idx = 2353
# Done
# idx = 2354
# Done
# idx = 2355
# Done
# idx = 2356
# Done
# idx = 2357
# Done
# idx = 2358
# Done
# idx = 2359
# Done
# idx = 2360
# Done
# idx = 2361
# Done
# idx = 2362
# Done
# idx = 2363
# Done
# idx = 2364
# Done
# idx = 2365
# Done
# idx = 2366
# Done
# idx = 2367
# Done
# idx = 2368
# Done
# idx = 2369
# Done
# idx = 2370
# Done
# idx = 2371
# Done
# idx = 2372
# Done
# idx = 2373
# Done
# idx = 2374
# Done
# idx = 2375
# Done
# idx = 2376
# Done
# idx = 2377
# Done
# idx = 2378
# Done
# idx = 2379
# Done
# idx = 2380
# Done
# idx = 2381
# Done
# idx = 2382
# Done
# idx = 2383
# Done
# idx = 2384
# Done
# idx = 2385
# Done
# idx = 2386
# Done
# idx = 2387
# Done
# idx = 2388
# Done
# idx = 2389
# Done
# idx = 2390
# Done
# idx = 2391
# Done
# idx = 2392
# Done
# idx = 2393
# Done
# idx = 2394
# Done
# idx = 2395
# Done
# idx = 2396
# Done
# idx = 2397
# Done
# idx = 2398
# Done
# idx = 2399
# Done
# idx = 2400
# Done
# idx = 2401
# Done
# idx = 2402
# Done
# idx = 2403
# Done
# idx = 2404
# Done
# idx = 2405
# Done
# idx = 2406
# Done
# idx = 2407
# Done
# idx = 2408
# Done
# idx = 2409
# Done
# idx = 2410
# Done
# idx = 2411
# Done
# idx = 2412
# Done
# idx = 2413
# Done
# idx = 2414
# Done
# idx = 2415
# Done
# idx = 2416
# Done
# idx = 2417
# Done
# idx = 2418
# Done
# idx = 2419
# Done
# idx = 2420
# Done
# idx = 2421
# Done
# idx = 2422
# Done
# idx = 2423
# Done
# idx = 2424
# Done
# idx = 2425
# Done
# idx = 2426
# Done
# idx = 2427
# Done
# idx = 2428
# Done
# idx = 2429
# Done
# idx = 2430
# Done
# idx = 2431
# Done
# idx = 2432
# Done
# idx = 2433
# Done
# idx = 2434
# Done
# idx = 2435
# Done
# idx = 2436
# Done
# idx = 2437
# Done
# idx = 2438
# Done
# idx = 2439
# Done
# idx = 2440
# Done
# idx = 2441
# Done
# idx = 2442
# Done
# idx = 2443
# Done
# idx = 2444
# Done
# idx = 2445
# Done
# idx = 2446
# Done
# idx = 2447
# Done
# idx = 2448
# Done
# idx = 2449
# Done
# idx = 2450
# Done
# idx = 2451
# Done
# idx = 2452
# TimeOut ERROR
# idx = 2453
# Done
# idx = 2454
# Done
# idx = 2455
# Done
# idx = 2456
# Done
# idx = 2457
# Done
# idx = 2458
# Done
# idx = 2459
# Done
# idx = 2460
# Done
# idx = 2461
# Done
# idx = 2462
# Done
# idx = 2463
# Done
# idx = 2464
# Done
# idx = 2465
# Done
# idx = 2466
# Done
# idx = 2467
# Done
# idx = 2468
# Done
# idx = 2469
# Done
# idx = 2470
# Done
# idx = 2471
# Done
# idx = 2472
# Done
# idx = 2473
# Done
# idx = 2474
# Done
# idx = 2475
# Done
# idx = 2476
# Done
# idx = 2477
# Done
# idx = 2478
# Done
# idx = 2479
# Done
# idx = 2480
# Done
# idx = 2481
# Done
# idx = 2482
# Done
# idx = 2483
# Done
# idx = 2484
# Done
# idx = 2485
# Done
# idx = 2486
# Done
# idx = 2487
# Done
# idx = 2488
# Done
# idx = 2489
# Done
# idx = 2490
# Done
# idx = 2491
# Done
# idx = 2492
# Done
# idx = 2493
# Done
# idx = 2494
# Done
# idx = 2495
# Done
# idx = 2496
# Done
# idx = 2497
# Done
# idx = 2498
# Done
# idx = 2499
# Done
# idx = 2500
# Done
# idx = 2501
# Done
# idx = 2502
# Done
# idx = 2503
# Done
# idx = 2504
# Done
# idx = 2505
# Done
# idx = 2506
# Done
# idx = 2507
# Done
# idx = 2508
# Done
# idx = 2509
# Done
# idx = 2510
# Done
# idx = 2511
# Done
# idx = 2512
# Done
# idx = 2513
# Done
# idx = 2514
# Done
# idx = 2515
# Done
# idx = 2516
# Done
# idx = 2517
# Done
# idx = 2518
# Done
# idx = 2519
# Done
# idx = 2520
# Done
# idx = 2521
# Done
# idx = 2522
# Done
# idx = 2523
# Done
# idx = 2524
# Done
# idx = 2525
# Done
# idx = 2526
# Done
# idx = 2527
# Done
# idx = 2528
# Done
# idx = 2529
# Done
# idx = 2530
# Done
# idx = 2531
# Done
# idx = 2532
# Done
# idx = 2533
# Done
# idx = 2534
# Done
# idx = 2535
# Done
# idx = 2536
# Done
# idx = 2537
# Done
# idx = 2538
# Done
# idx = 2539
# Done
# idx = 2540
# Done
# idx = 2541
# Done
# idx = 2542
# Done
# idx = 2543
# Done
# idx = 2544
# Done
# idx = 2545
# Done
# idx = 2546
# Done
# idx = 2547
# Done
# idx = 2548
# Done
# idx = 2549
# Done
# idx = 2550
# Done
# idx = 2551
# Done
# idx = 2552
# Done
# idx = 2553
# Done
# idx = 2554
# Done
# idx = 2555
# Done
# idx = 2556
# Done
# idx = 2557
# Done
# idx = 2558
# Done
# idx = 2559
# Done
# idx = 2560
# Done
# idx = 2561
# Done
# idx = 2562
# Done
# idx = 2563
# Done
# idx = 2564
# Done
# idx = 2565
# Done
# idx = 2566
# Done
# idx = 2567
# Done
# idx = 2568
# Done
# idx = 2569
# Done
# idx = 2570
# Done
# idx = 2571
# Done
# idx = 2572
# Done
# idx = 2573
# Done
# idx = 2574
# Done
# idx = 2575
# Done
# idx = 2576
# Done
# idx = 2577
# Done
# idx = 2578
# Done
# idx = 2579
# Done
# idx = 2580
# Done
# idx = 2581
# Done
# idx = 2582
# Done
# idx = 2583
# Done
# idx = 2584
# Done
# idx = 2585
# Done
# idx = 2586
# Done
# idx = 2587
# Done
# idx = 2588
# Done
# idx = 2589
# Done
# idx = 2590
# Done
# idx = 2591
# Done
# idx = 2592
# Done
# idx = 2593
# Done
# idx = 2594
# Done
# idx = 2595
# Done
# idx = 2596
# Done
# idx = 2597
# Done
# idx = 2598
# Done
# idx = 2599
# Done
# idx = 2600
# Done
# idx = 2601
# Done
# idx = 2602
# Done
# idx = 2603
# Done
# idx = 2604
# Done
# idx = 2605
# Done
# idx = 2606
# Done
# idx = 2607
# Done
# idx = 2608
# Done
# idx = 2609
# Done
# idx = 2610
# Done
# idx = 2611
# Done
# idx = 2612
# Done
# idx = 2613
# Done
# idx = 2614
# Done
# idx = 2615
# Done
# idx = 2616
# Done
# idx = 2617
# Done
# idx = 2618
# Done
# idx = 2619
# Done
# idx = 2620
# Done
# idx = 2621
# Done
# idx = 2622
# Done
# idx = 2623
# Done
# idx = 2624
# Done
# idx = 2625
# Done
# idx = 2626
# Done
# idx = 2627
# Done
# idx = 2628
# Done
# idx = 2629
# Done
# idx = 2630
# Done
# idx = 2631
# Done
# idx = 2632
# Done
# idx = 2633
# Done
# idx = 2634
# Done
# idx = 2635
# Done
# idx = 2636
# Done
# idx = 2637
# Done
# idx = 2638
# Done
# idx = 2639
# Done
# idx = 2640
# Done
# idx = 2641
# Done
# idx = 2642
# Done
# idx = 2643
# Done
# idx = 2644
# Done
# idx = 2645
# Done
# idx = 2646
# Done
# idx = 2647
# Done
# idx = 2648
# Done
# idx = 2649
# Done
# idx = 2650
# Done
# idx = 2651
# Done
# idx = 2652
# Done
# idx = 2653
# Done
# idx = 2654
# Done
# idx = 2655
# Done
# idx = 2656
# Done
# idx = 2657
# Done
# idx = 2658
# Done
# idx = 2659
# Done
# idx = 2660
# Done
# idx = 2661
# Done
# idx = 2662
# Done
# idx = 2663
# Done
# idx = 2664
# Done
# idx = 2665
# Done
# idx = 2666
# Done
# idx = 2667
# Done
# idx = 2668
# Done
# idx = 2669
# Done
# idx = 2670
# Done
# idx = 2671
# Done
# idx = 2672
# Done
# idx = 2673
# Done
# idx = 2674
# Done
# idx = 2675
# Done
# idx = 2676
# Done
# idx = 2677
# Done
# idx = 2678
# Done
# idx = 2679
# Done
# idx = 2680
# Done
# idx = 2681
# Done
# idx = 2682
# Done
# idx = 2683
# Done
# idx = 2684
# Done
# idx = 2685
# Done
# idx = 2686
# Done
# idx = 2687
# Done
# idx = 2688
# Done
# idx = 2689
# Done
# idx = 2690
# Done
# idx = 2691
# Done
# idx = 2692
# Done
# idx = 2693
# Done
# idx = 2694
# Done
# idx = 2695
# Done
# idx = 2696
# Done
# idx = 2697
# Done
# idx = 2698
# Done
# idx = 2699
# Done
# idx = 2700
# Done
# idx = 2701
# Done
# idx = 2702
# Done
# idx = 2703
# Done
# idx = 2704
# Done
# idx = 2705
# Done
# idx = 2706
# Done
# idx = 2707
# Done
# idx = 2708
# Done
# idx = 2709
# Done
# idx = 2710
# Done
# idx = 2711
# Done
# idx = 2712
# Done
# idx = 2713
# TimeOut ERROR
# idx = 2714
# Done
# idx = 2715
# Done
# idx = 2716
# Done
# idx = 2717
# Done
# idx = 2718
# Done
# idx = 2719
# Done
# idx = 2720
# Done
# idx = 2721
# Done
# idx = 2722
# Done
# idx = 2723
# Done
# idx = 2724
# Done
# idx = 2725
# Done
# idx = 2726
# Done
# idx = 2727
# Done
# idx = 2728
# Done
# idx = 2729
# Done
# idx = 2730
# Done
# idx = 2731
# Done
# idx = 2732
# Done
# idx = 2733
# Done
# idx = 2734
# Done
# idx = 2735
# Done
# idx = 2736
# Done
# idx = 2737
# Done
# idx = 2738
# Done
# idx = 2739
# Done
# idx = 2740
# Done
# idx = 2741
# Done
# idx = 2742
# Done
# idx = 2743
# Done
# idx = 2744
# Done
# idx = 2745
# Done
# idx = 2746
# Done
# idx = 2747
# Done
# idx = 2748
# Done
# idx = 2749
# Done
# idx = 2750
# Done
# idx = 2751
# Done
# idx = 2752
# Done
# idx = 2753
# Done
# idx = 2754
# Done
# idx = 2755
# Done
# idx = 2756
# Done
# idx = 2757
# Done
# idx = 2758
# Done
# idx = 2759
# Done
# idx = 2760
# Done
# idx = 2761
# Done
# idx = 2762
# Done
# idx = 2763
# Done
# idx = 2764
# Done
# idx = 2765
# Done
# idx = 2766
# Done
# idx = 2767
# Done
# idx = 2768
# Done
# idx = 2769
# Done
# idx = 2770
# Done
# idx = 2771
# Done
# idx = 2772
# Done
# idx = 2773
# Done
# idx = 2774
# Done
# idx = 2775
# Done
# idx = 2776
# Done
# idx = 2777
# Done
# idx = 2778
# Done
# idx = 2779
# Done
# idx = 2780
# Done
# idx = 2781
# Done
# idx = 2782
# Done
# idx = 2783
# Done
# idx = 2784
# Done
# idx = 2785
# Done
# idx = 2786
# Done
# idx = 2787
# Done
# idx = 2788
# Done
# idx = 2789
# Done
# idx = 2790
# Done
# idx = 2791
# Done
# idx = 2792
# Done
# idx = 2793
# Done
# idx = 2794
# Done
# idx = 2795
# Done
# idx = 2796
# Done
# idx = 2797
# Done
# idx = 2798
# Done
# idx = 2799
# Done
# idx = 2800
# Done
# idx = 2801
# Done
# idx = 2802
# Done
# idx = 2803
# Done
# idx = 2804
# Done
# idx = 2805
# Done
# idx = 2806
# Done
# idx = 2807
# Done
# idx = 2808
# Done
# idx = 2809
# Done
# idx = 2810
# Done
# idx = 2811
# Done
# idx = 2812
# Done
# idx = 2813
# Done
# idx = 2814
# Done
# idx = 2815
# Done
# idx = 2816
# Done
# idx = 2817
# Done
# idx = 2818
# Done
# idx = 2819
# Done
# idx = 2820
# Done
# idx = 2821
# Done
# idx = 2822
# Done
# idx = 2823
# Done
# idx = 2824
# Done
# idx = 2825
# Done
# idx = 2826
# Done
# idx = 2827
# Done
# idx = 2828
# Done
# idx = 2829
# Done
# idx = 2830
# Done
# idx = 2831
# Done
# idx = 2832
# Done
# idx = 2833
# Done
# idx = 2834
# Done
# idx = 2835
# Done
# idx = 2836
# Done
# idx = 2837
# Done
# idx = 2838
# Done
# idx = 2839
# Done
# idx = 2840
# Done
# idx = 2841
# Done
# idx = 2842
# Done
# idx = 2843
# Done
# idx = 2844
# Done
# idx = 2845
# Done
# idx = 2846
# Done
# idx = 2847
# Done
# idx = 2848
# Done
# idx = 2849
# Done
# idx = 2850
# Done
# idx = 2851
# Done
# idx = 2852
# Done
# idx = 2853
# Done
# idx = 2854
# Done
# idx = 2855
# Done
# idx = 2856
# Done
# idx = 2857
# Done
# idx = 2858
# Done
# idx = 2859
# Done
# idx = 2860
# Done
# idx = 2861
# Done
# idx = 2862
# Done
# idx = 2863
# Done
# idx = 2864
# Done
# idx = 2865
# Done
# idx = 2866
# Done
# idx = 2867
# Done
# idx = 2868
# Done
# idx = 2869
# Done
# idx = 2870
# Done
# idx = 2871
# Done
# idx = 2872
# Done
# idx = 2873
# Done
# idx = 2874
# Done
# idx = 2875
# Done
# idx = 2876
# Done
# idx = 2877
# Done
# idx = 2878
# Done
# idx = 2879
# Done
# idx = 2880
# Done
# idx = 2881
# Done
# idx = 2882
# Done
# idx = 2883
# Done
# idx = 2884
# Done
# idx = 2885
# Done
# idx = 2886
# Done
# idx = 2887
# Done
# idx = 2888
# Done
# idx = 2889
# Done
# idx = 2890
# Done
# idx = 2891
# Done
# idx = 2892
# Done
# idx = 2893
# Done
# idx = 2894
# Done
# idx = 2895
# Done
# idx = 2896
# Done
# idx = 2897
# Done
# idx = 2898
# Done
# idx = 2899
# Done
# idx = 2900
# Done
# idx = 2901
# Done
# idx = 2902
# Done
# idx = 2903
# Done
# idx = 2904
# Done
# idx = 2905
# Done
# idx = 2906
# Done
# idx = 2907
# Done
# idx = 2908
# Done
# idx = 2909
# Done
# idx = 2910
# Done
# idx = 2911
# Done
# idx = 2912
# Done
# idx = 2913
# Done
# idx = 2914
# Done
# idx = 2915
# Done
# idx = 2916
# Done
# idx = 2917
# Done
# idx = 2918
# Done
# idx = 2919
# Done
# idx = 2920
# Done
# idx = 2921
# Done
# idx = 2922
# Done
# idx = 2923
# Done
# idx = 2924
# Done
# idx = 2925
# Done
# idx = 2926
# Done
# idx = 2927
# Done
# idx = 2928
# Done
# idx = 2929
# Done
# idx = 2930
# Done
# idx = 2931
# Done
# idx = 2932
# Done
# idx = 2933
# Done
# idx = 2934
# Done
# idx = 2935
# Done
# idx = 2936
# Done
# idx = 2937
# Done
# idx = 2938
# TimeOut ERROR
# idx = 2939
# Done
# idx = 2940
# Done
# idx = 2941
# Done
# idx = 2942
# Done
# idx = 2943
# Done
# idx = 2944
# TimeOut ERROR
# idx = 2945
# Done
# idx = 2946
# Done
# idx = 2947
# Done
# idx = 2948
# ERROR1
# idx = 2949
# Done
# idx = 2950
# Done
# idx = 2951
# Done
# idx = 2952
# Done
# idx = 2953
# Done
# idx = 2954
# Done
# idx = 2955
# Done
# idx = 2956
# Done
# idx = 2957
# Done
# idx = 2958
# Done
# idx = 2959
# Done
# idx = 2960
# Done
# idx = 2961
# Done
# idx = 2962
# Done
# idx = 2963
# Done
# idx = 2964
# Done
# idx = 2965
# Done
# idx = 2966
# Done
# idx = 2967
# Done
# idx = 2968
# Done
# idx = 2969
# Done
# idx = 2970
# Done
# idx = 2971
# Done
# idx = 2972
# Done
# idx = 2973
# Done
# idx = 2974
# Done
# idx = 2975
# Done
# idx = 2976
# Done
# idx = 2977
# Done
# idx = 2978
# Done
# idx = 2979
# Done
# idx = 2980
# Done
# idx = 2981
# Done
# idx = 2982
# Done
# idx = 2983
# Done
# idx = 2984
# Done
# idx = 2985
# Done
# idx = 2986
# Done
# idx = 2987
# Done
# idx = 2988
# Done
# idx = 2989
# Done
# idx = 2990
# Done
# idx = 2991
# Done
# idx = 2992
# Done
# idx = 2993
# Done
# idx = 2994
# Done
# idx = 2995
# Done
# idx = 2996
# Done
# idx = 2997
# Done
# idx = 2998
# Done
# idx = 2999
# Done
# idx = 3000
# Done
# idx = 3001
# Done
# idx = 3002
# Done
# idx = 3003
# Done
# idx = 3004
# Done
# idx = 3005
# Done
# idx = 3006
# Done
# idx = 3007
# Done
# idx = 3008
# Done
# idx = 3009
# Done
# idx = 3010
# Done
# idx = 3011
# Done
# idx = 3012
# Done
# idx = 3013
# Done
# idx = 3014
# Done
# idx = 3015
# Done
# idx = 3016
# Done
# idx = 3017
# Done
# idx = 3018
# Done
# idx = 3019
# Done
# idx = 3020
# TimeOut ERROR
# idx = 3021
# Done
# idx = 3022
# Done
# idx = 3023
# Done
# idx = 3024
# Done
# idx = 3025
# Done
# idx = 3026
# Done
# idx = 3027
# Done
# idx = 3028
# Done
# idx = 3029
# Done
# idx = 3030
# Done
# idx = 3031
# Done
# idx = 3032
# Done
# idx = 3033
# Done
# idx = 3034
# Done
# idx = 3035
# Done
# idx = 3036
# Done
# idx = 3037
# Done
# idx = 3038
# Done
# idx = 3039
# Done
# idx = 3040
# Done
# idx = 3041
# Done
# idx = 3042
# Done
# idx = 3043
# Done
# idx = 3044
# Done
# idx = 3045
# Done
# idx = 3046
# Done
# idx = 3047
# Done
# idx = 3048
# Done
# idx = 3049
# Done
# idx = 3050
# Done
# idx = 3051
# Done
# idx = 3052
# Done
# idx = 3053
# Done
# idx = 3054
# Done
# idx = 3055
# Done
# idx = 3056
# Done
# idx = 3057
# Done
# idx = 3058
# Done
# idx = 3059
# Done
# idx = 3060
# Done
# idx = 3061
# Done
# idx = 3062
# Done
# idx = 3063
# Done
# ...
# Done
# idx = 17820
# Done
# idx = 17821
# Done
# idx = 17822
# Done
# idx = 17823
# Done
# idx = 17824
# Done
# idx = 17825
# Done
# idx = 17826
# Done
# idx = 17827
# Done
# idx = 17828
# Done
# idx = 17829
# Done
# idx = 17830
# Done
# idx = 17831
# Done
# idx = 17832
# Done
# idx = 17833
# Done
# idx = 17834
# Done
# idx = 17835
# Done
# idx = 17836
# Done
# idx = 17837
# Done
# idx = 17838
# Done
# idx = 17839
# Done
# idx = 17840
# Done
# idx = 17841
# Done
# idx = 17842
# Done
# idx = 17843
# Done
# idx = 17844
# Done
# idx = 17845
# Done
# idx = 17846
# Done
# idx = 17847
# Done
# idx = 17848
# Done
# idx = 17849
# Done
# idx = 17850
# Done
# idx = 17851
# Done
# idx = 17852
# Done
# idx = 17853
# Done
# idx = 17854
# Done
# idx = 17855
# Done
# idx = 17856
# Done
# idx = 17857
# Done
# idx = 17858
# Done
# idx = 17859
# Done
# idx = 17860
# Done
# idx = 17861
# Done
# idx = 17862
# Done
# idx = 17863
# Done
# idx = 17864
# Done
# idx = 17865
# Done
# idx = 17866
# Done
# idx = 17867
# Done
# idx = 17868
# Done
# idx = 17869
# Done
# idx = 17870
# Done
# idx = 17871
# Done
# idx = 17872
# Done
# idx = 17873
# Done
# idx = 17874
# Done
# idx = 17875
# Done
# idx = 17876
# Done
# idx = 17877
# Done
# idx = 17878
# Done
# idx = 17879
# Done
# idx = 17880
# Done
# idx = 17881
# Done
# idx = 17882
# Done
# idx = 17883
# Done
# idx = 17884
# Done
# idx = 17885
# Done
# idx = 17886
# Done
# idx = 17887
# Done
# idx = 17888
# Done
# idx = 17889
# Done
# idx = 17890
# Done
# idx = 17891
# Done
# idx = 17892
# Done
# idx = 17893
# Done
# idx = 17894
# Done
# idx = 17895
# Done
# idx = 17896
# Done
# idx = 17897
# Done
# idx = 17898
# Done
# idx = 17899
# Done
# idx = 17900
# Done
# idx = 17901
# Done
# idx = 17902
# Done
# idx = 17903
# Done
# idx = 17904
# Done
# idx = 17905
# Done
# idx = 17906
# Done
# idx = 17907
# Done
# idx = 17908
# Done
# idx = 17909
# Done
# idx = 17910
# Done
# idx = 17911
# Done
# idx = 17912
# Done
# idx = 17913
# Done
# idx = 17914
# Done
# idx = 17915
# Done
# idx = 17916
# Done
# idx = 17917
# Done
# idx = 17918
# Done
# idx = 17919
# Done
# idx = 17920
# Done
# idx = 17921
# Done
# idx = 17922
# Done
# idx = 17923
# Done
# idx = 17924
# Done
# idx = 17925
# Done
# idx = 17926
# Done
# idx = 17927
# Done
# idx = 17928
# Done
# idx = 17929
# Done
# idx = 17930
# Done
# idx = 17931
# Done
# idx = 17932
# Done
# idx = 17933
# Done
# idx = 17934
# Done
# idx = 17935
# Done
# idx = 17936
# Done
# idx = 17937
# Done
# idx = 17938
# Done
# idx = 17939
# Done
# idx = 17940
# Done
# idx = 17941
# Done
# idx = 17942
# Done
# idx = 17943
# Done
# idx = 17944
# Done
# idx = 17945
# Done
# idx = 17946
# Done
# idx = 17947
# Done
# idx = 17948
# Done
# idx = 17949
# Done
# idx = 17950
# Done
# idx = 17951
# Done
# idx = 17952
# Done
# idx = 17953
# Done
# idx = 17954
# Done
# idx = 17955
# Done
# idx = 17956
# Done
# idx = 17957
# Done
# idx = 17958
# Done
# idx = 17959
# Done
# idx = 17960
# Done
# idx = 17961
# Done
# idx = 17962
# Done
# idx = 17963
# Done
# idx = 17964
# Done
# idx = 17965
# Done
# idx = 17966
# Done
# idx = 17967
# Done
# idx = 17968
# Done
# idx = 17969
# Done
# idx = 17970
# Done
# idx = 17971
# Done
# idx = 17972
# Done
# idx = 17973
# Done
# idx = 17974
# Done
# idx = 17975
# Done
# idx = 17976
# Done
# idx = 17977
# Done
# idx = 17978
# Done
# idx = 17979
# Done
# idx = 17980
# Done
# idx = 17981
# Done
# idx = 17982
# Done
# idx = 17983
# Done
# idx = 17984
# Done
# idx = 17985
# Done
# idx = 17986
# Done
# idx = 17987
# Done
# idx = 17988
# Done
# idx = 17989
# Done
# idx = 17990
# Done
# idx = 17991
# Done
# idx = 17992
# Done
# idx = 17993
# Done
# idx = 17994
# Done
# idx = 17995
# Done
# idx = 17996
# Done
# idx = 17997
# Done
# idx = 17998
# Done
# idx = 17999
# Done
# idx = 18000
# Done
# idx = 18001
# Done
# idx = 18002
# Done
# idx = 18003
# Done
# idx = 18004
# Done
# idx = 18005
# Done
# idx = 18006
# Done
# idx = 18007
# Done
# idx = 18008
# Done
# idx = 18009
# Done
# idx = 18010
# Done
# idx = 18011
# Done
# idx = 18012
# Done
# idx = 18013
# Done
# idx = 18014
# Done
# idx = 18015
# Done
# idx = 18016
# Done
# idx = 18017
# Done
# idx = 18018
# Done
# idx = 18019
# Done
# idx = 18020
# Done
# idx = 18021
# Done
# idx = 18022
# Done
# idx = 18023
# Done
# idx = 18024
# Done
# idx = 18025
# Done
# idx = 18026
# Done
# idx = 18027
# Done
# idx = 18028
# Done
# idx = 18029
# Done
# idx = 18030
# Done
# idx = 18031
# Done
# idx = 18032
# Done
# idx = 18033
# Done
# idx = 18034
# Done
# idx = 18035
# Done
# idx = 18036
# Done
# idx = 18037
# Done
# idx = 18038
# Done
# idx = 18039
# Done
# idx = 18040
# Done
# idx = 18041
# Done
# idx = 18042
# Done
# idx = 18043
# Done
# idx = 18044
# Done
# idx = 18045
# Done
# idx = 18046
# Done
# idx = 18047
# Done
# idx = 18048
# Done
# idx = 18049
# Done
# idx = 18050
# Done
# idx = 18051
# Done
# idx = 18052
# Done
# idx = 18053
# Done
# idx = 18054
# Done
# idx = 18055
# Done
# idx = 18056
# Done
# idx = 18057
# Done
# idx = 18058
# Done
# idx = 18059
# Done
# idx = 18060
# Done
# idx = 18061
# Done
# idx = 18062
# Done
# idx = 18063
# Done
# idx = 18064
# Done
# idx = 18065
# Done
# idx = 18066
# Done
# idx = 18067
# Done
# idx = 18068
# Done
# idx = 18069
# Done
# idx = 18070
# Done
# idx = 18071
# Done
# idx = 18072
# Done
# idx = 18073
# Done
# idx = 18074
# Done
# idx = 18075
# Done
# idx = 18076
# Done
# idx = 18077
# Done
# idx = 18078
# Done
# idx = 18079
# Done
# idx = 18080
# Done
# idx = 18081
# Done
# idx = 18082
# Done
# idx = 18083
# Done
# idx = 18084
# Done
# idx = 18085
# Done
# idx = 18086
# Done
# idx = 18087
# Done
# idx = 18088
# Done
# idx = 18089
# Done
# idx = 18090
# Done
# idx = 18091
# Done
# idx = 18092
# Done
# idx = 18093
# Done
# idx = 18094
# Done
# idx = 18095
# Done
# idx = 18096
# Done
# idx = 18097
# Done
# idx = 18098
# Done
# idx = 18099
# Done
# idx = 18100
# Done
# idx = 18101
# Done
# idx = 18102
# Done
# idx = 18103
# Done
# idx = 18104
# Done
# idx = 18105
# Done
# idx = 18106
# Done
# idx = 18107
# Done
# idx = 18108
# Done
# idx = 18109
# Done
# idx = 18110
# Done
# idx = 18111
# Done
# idx = 18112
# Done
# idx = 18113
# Done
# idx = 18114
# Done
# idx = 18115
# Done
# idx = 18116
# Done
# idx = 18117
# Done
# idx = 18118
# Done
# idx = 18119
# Done
# idx = 18120
# Done
# idx = 18121
# Done
# idx = 18122
# Done
# idx = 18123
# Done
# idx = 18124
# Done
# idx = 18125
# Done
# idx = 18126
# Done
# idx = 18127
# Done
# idx = 18128
# Done
# idx = 18129
# Done
# idx = 18130
# Done
# idx = 18131
# Done
# idx = 18132
# Done
# idx = 18133
# Done
# idx = 18134
# Done
# idx = 18135
# Done
# idx = 18136
# Done
# idx = 18137
# Done
# idx = 18138
# ERROR1
# idx = 18139
# Done
# idx = 18140
# Done
# idx = 18141
# Done
# idx = 18142
# Done
# idx = 18143
# Done
# idx = 18144
# Done
# idx = 18145
# Done
# idx = 18146
# Done
# idx = 18147
# Done
# idx = 18148
# Done
# idx = 18149
# Done
# idx = 18150
# Done
# idx = 18151
# Done
# idx = 18152
# Done
# idx = 18153
# Done
# idx = 18154
# Done
# idx = 18155
# Done
# idx = 18156
# Done
# idx = 18157
# Done
# idx = 18158
# Done
# idx = 18159
# Done
# idx = 18160
# Done
# idx = 18161
# Done
# idx = 18162
# Done
# idx = 18163
# Done
# idx = 18164
# Done
# idx = 18165
# Done
# idx = 18166
# Done
# idx = 18167
# Done
# idx = 18168
# Done
# idx = 18169
# Done
# idx = 18170
# Done
# idx = 18171
# Done
# idx = 18172
# Done
# idx = 18173
# Done
# idx = 18174
# Done
# idx = 18175
# Done
# idx = 18176
# Done
# idx = 18177
# Done
# idx = 18178
# Done
# idx = 18179
# Done
# idx = 18180
# Done
# idx = 18181
# Done
# idx = 18182
# Done
# idx = 18183
# Done
# idx = 18184
# Done
# idx = 18185
# Done
# idx = 18186
# Done
# idx = 18187
# Done
# idx = 18188
# Done
# idx = 18189
# Done
# idx = 18190
# Done
# idx = 18191
# Done
# idx = 18192
# Done
# idx = 18193
# Done
# idx = 18194
# Done
# idx = 18195
# Done
# idx = 18196
# Done
# idx = 18197
# Done
# idx = 18198
# Done
# idx = 18199
# Done
# idx = 18200
# Done
# idx = 18201
# Done
# idx = 18202
# Done
# idx = 18203
# Done
# idx = 18204
# Done
# idx = 18205
# Done
# idx = 18206
# Done
# idx = 18207
# Done
# idx = 18208
# Done
# idx = 18209
# Done
# idx = 18210
# Done
# idx = 18211
# Done
# idx = 18212
# Done
# idx = 18213
# Done
# idx = 18214
# Done
# idx = 18215
# Done
# idx = 18216
# Done
# idx = 18217
# Done
# idx = 18218
# Done
# idx = 18219
# Done
# idx = 18220
# Done
# idx = 18221
# Done
# idx = 18222
# Done
# idx = 18223
# Done
# idx = 18224
# Done
# idx = 18225
# Done
# idx = 18226
# Done
# idx = 18227
# Done
# idx = 18228
# Done
# idx = 18229
# Done
# idx = 18230
# Done
# idx = 18231
# Done
# idx = 18232
# Done
# idx = 18233
# Done
# idx = 18234
# Done
# idx = 18235
# Done
# idx = 18236
# Done
# idx = 18237
# Done
# idx = 18238
# Done
# idx = 18239
# Done
# idx = 18240
# Done
# idx = 18241
# Done
# idx = 18242
# Done
# idx = 18243
# Done
# idx = 18244
# Done
# idx = 18245
# Done
# idx = 18246
# Done
# idx = 18247
# Done
# idx = 18248
# Done
# idx = 18249
# Done
# idx = 18250
# Done
# idx = 18251
# Done
# idx = 18252
# Done
# idx = 18253
# Done
# idx = 18254
# Done
# idx = 18255
# Done
# idx = 18256
# Done
# idx = 18257
# ERROR1
# idx = 18258
# Done
# idx = 18259
# Done
# idx = 18260
# Done
# idx = 18261
# Done
# idx = 18262
# Done
# idx = 18263
# Done
# idx = 18264
# Done
# idx = 18265
# Done
# idx = 18266
# Done
# idx = 18267
# Done
# idx = 18268
# Done
# idx = 18269
# Done
# idx = 18270
# Done
# idx = 18271
# Done
# idx = 18272
# Done
# idx = 18273
# Done
# idx = 18274
# Done
# idx = 18275
# Done
# idx = 18276
# Done
# idx = 18277
# Done
# idx = 18278
# Done
# idx = 18279
# Done
# idx = 18280
# Done
# idx = 18281
# Done
# idx = 18282
# Done
# idx = 18283
# Done
# idx = 18284
# Done
# idx = 18285
# Done
# idx = 18286
# Done
# idx = 18287
# Done
# idx = 18288
# Done
# idx = 18289
# Done
# idx = 18290
# Done
# idx = 18291
# Done
# idx = 18292
# Done
# idx = 18293
# Done
# idx = 18294
# Done
# idx = 18295
# Done
# idx = 18296
# Done
# idx = 18297
# Done
# idx = 18298
# Done
# idx = 18299
# Done
# idx = 18300
# Done
# idx = 18301
# Done
# idx = 18302
# Done
# idx = 18303
# Done
# idx = 18304
# Done
# idx = 18305
# Done
# idx = 18306
# Done
# idx = 18307
# Done
# idx = 18308
# Done
# idx = 18309
# Done
# idx = 18310
# Done
# idx = 18311
# Done
# idx = 18312
# Done
# idx = 18313
# Done
# idx = 18314
# Done
# idx = 18315
# Done
# idx = 18316
# Done
# idx = 18317
# Done
# idx = 18318
# Done
# idx = 18319
# Done
# idx = 18320
# Done
# idx = 18321
# Done
# idx = 18322
# Done
# idx = 18323
# Done
# idx = 18324
# Done
# idx = 18325
# Done
# idx = 18326
# Done
# idx = 18327
# Done
# idx = 18328
# Done
# idx = 18329
# Done
# idx = 18330
# Done
# idx = 18331
# Done
# idx = 18332
# Done
# idx = 18333
# Done
# idx = 18334
# Done
# idx = 18335
# Done
# idx = 18336
# Done
# idx = 18337
# Done
# idx = 18338
# Done
# idx = 18339
# Done
# idx = 18340
# Done
# idx = 18341
# Done
# idx = 18342
# Done
# idx = 18343
# Done
# idx = 18344
# Done
# idx = 18345
# Done
# idx = 18346
# Done
# idx = 18347
# Done
# idx = 18348
# Done
# idx = 18349
# Done
# idx = 18350
# Done
# idx = 18351
# Done
# idx = 18352
# Done
# idx = 18353
# Done
# idx = 18354
# Done
# idx = 18355
# Done
# idx = 18356
# Done
# idx = 18357
# Done
# idx = 18358
# Done
# idx = 18359
# Done
# idx = 18360
# Done
# idx = 18361
# Done
# idx = 18362
# Done
# idx = 18363
# Done
# idx = 18364
# Done
# idx = 18365
# Done
# idx = 18366
# Done
# idx = 18367
# Done
# idx = 18368
# Done
# idx = 18369
# Done
# idx = 18370
# Done
# idx = 18371
# Done
# idx = 18372
# Done
# idx = 18373
# Done
# idx = 18374
# Done
# idx = 18375
# Done
# idx = 18376
# Done
# idx = 18377
# Done
# idx = 18378
# Done
# idx = 18379
# Done
# idx = 18380
# Done
# idx = 18381
# Done
# idx = 18382
# Done
# idx = 18383
# Done
# idx = 18384
# Done
# idx = 18385
# Done
# idx = 18386
# Done
# idx = 18387
# Done
# idx = 18388
# Done
# idx = 18389
# Done
# idx = 18390
# Done
# idx = 18391
# Done
# idx = 18392
# Done
# idx = 18393
# Done
# idx = 18394
# Done
# idx = 18395
# Done
# idx = 18396
# Done
# idx = 18397
# Done
# idx = 18398
# Done
# idx = 18399
# Done
# idx = 18400
# Done
# idx = 18401
# Done
# idx = 18402
# Done
# idx = 18403
# Done
# idx = 18404
# Done
# idx = 18405
# Done
# idx = 18406
# Done
# idx = 18407
# Done
# idx = 18408
# Done
# idx = 18409
# Done
# idx = 18410
# Done
# idx = 18411
# Done
# idx = 18412
# Done
# idx = 18413
# Done
# idx = 18414
# Done
# idx = 18415
# Done
# idx = 18416
# Done
# idx = 18417
# Done
# idx = 18418
# Done
# idx = 18419
# Done
# idx = 18420
# Done
# idx = 18421
# Done
# idx = 18422
# Done
# idx = 18423
# Done
# idx = 18424
# Done
# idx = 18425
# Done
# idx = 18426
# Done
# idx = 18427
# Done
# idx = 18428
# Done
# idx = 18429
# Done
# idx = 18430
# Done
# idx = 18431
# Done
# idx = 18432
# Done
# idx = 18433
# Done
# idx = 18434
# Done
# idx = 18435
# Done
# idx = 18436
# Done
# idx = 18437
# Done
# idx = 18438
# Done
# idx = 18439
# Done
# idx = 18440
# Done
# idx = 18441
# Done
# idx = 18442
# Done
# idx = 18443
# Done
# idx = 18444
# Done
# idx = 18445
# Done
# idx = 18446
# Done
# idx = 18447
# Done
# idx = 18448
# Done
# idx = 18449
# Done
# idx = 18450
# Done
# idx = 18451
# Done
# idx = 18452
# Done
# idx = 18453
# Done
# idx = 18454
# Done
# idx = 18455
# Done
# idx = 18456
# Done
# idx = 18457
# Done
# idx = 18458
# Done
# idx = 18459
# Done
# idx = 18460
# Done
# idx = 18461
# Done
# idx = 18462
# Done
# idx = 18463
# Done
# idx = 18464
# Done
# idx = 18465
# Done
# idx = 18466
# Done
# idx = 18467
# Done
# idx = 18468
# Done
# idx = 18469
# Done
# idx = 18470
# Done
# idx = 18471
# Done
# idx = 18472
# Done
# idx = 18473
# Done
# idx = 18474
# Done
# idx = 18475
# Done
# idx = 18476
# Done
# idx = 18477
# Done
# idx = 18478
# Done
# idx = 18479
# Done
# idx = 18480
# Done
# idx = 18481
# Done
# idx = 18482
# Done
# idx = 18483
# Done
# idx = 18484
# Done
# idx = 18485
# Done
# idx = 18486
# Done
# idx = 18487
# Done
# idx = 18488
# Done
# idx = 18489
# Done
# idx = 18490
# Done
# idx = 18491
# Done
# idx = 18492
# Done
# idx = 18493
# Done
# idx = 18494
# Done
# idx = 18495
# Done
# idx = 18496
# Done
# idx = 18497
# Done
# idx = 18498
# Done
# idx = 18499
# Done
# idx = 18500
# Done
# idx = 18501
# Done
# idx = 18502
# Done
# idx = 18503
# Done
# idx = 18504
# Done
# idx = 18505
# Done
# idx = 18506
# Done
# idx = 18507
# Done
# idx = 18508
# Done
# idx = 18509
# Done
# idx = 18510
# Done
# idx = 18511
# Done
# idx = 18512
# Done
# idx = 18513
# Done
# idx = 18514
# Done
# idx = 18515
# Done
# idx = 18516
# Done
# idx = 18517
# Done
# idx = 18518
# Done
# idx = 18519
# Done
# idx = 18520
# Done
# idx = 18521
# Done
# idx = 18522
# Done
# idx = 18523
# Done
# idx = 18524
# Done
# idx = 18525
# Done
# idx = 18526
# Done
# idx = 18527
# Done
# idx = 18528
# Done
# idx = 18529
# Done
# idx = 18530
# Done
# idx = 18531
# Done
# idx = 18532
# Done
# idx = 18533
# Done
# idx = 18534
# Done
# idx = 18535
# Done
# idx = 18536
# Done
# idx = 18537
# Done
# idx = 18538
# Done
# idx = 18539
# Done
# idx = 18540
# Done
# idx = 18541
# Done
# idx = 18542
# Done
# idx = 18543
# Done
# idx = 18544
# Done
# idx = 18545
# Done
# idx = 18546
# Done
# idx = 18547
# Done
# idx = 18548
# Done
# idx = 18549
# Done
# idx = 18550
# Done
# idx = 18551
# Done
# idx = 18552
# Done
# idx = 18553
# Done
# idx = 18554
# Done
# idx = 18555
# Done
# idx = 18556
# Done
# idx = 18557
# Done
# idx = 18558
# Done
# idx = 18559
# Done
# idx = 18560
# Done
# idx = 18561
# Done
# idx = 18562
# Done
# idx = 18563
# Done
# idx = 18564
# Done
# idx = 18565
# Done
# idx = 18566
# Done
# idx = 18567
# Done
# idx = 18568
# Done
# idx = 18569
# Done
# idx = 18570
# Done
# idx = 18571
# Done
# idx = 18572
# Done
# idx = 18573
# Done
# idx = 18574
# Done
# idx = 18575
# Done
# idx = 18576
# Done
# idx = 18577
# Done
# idx = 18578
# Done
# idx = 18579
# Done
# idx = 18580
# Done
# idx = 18581
# Done
# idx = 18582
# Done
# idx = 18583
# Done
# idx = 18584
# Done
# idx = 18585
# Done
# idx = 18586
# Done
# idx = 18587
# Done
# idx = 18588
# Done
# idx = 18589
# Done
# idx = 18590
# Done
# idx = 18591
# Done
# idx = 18592
# Done
# idx = 18593
# Done
# idx = 18594
# Done
# idx = 18595
# Done
# idx = 18596
# Done
# idx = 18597
# Done
# idx = 18598
# Done
# idx = 18599
# Done
# idx = 18600
# Done
# idx = 18601
# Done
# idx = 18602
# Done
# idx = 18603
# Done
# idx = 18604
# Done
# idx = 18605
# Done
# idx = 18606
# Done
# idx = 18607
# Done
# idx = 18608
# Done
# idx = 18609
# Done
# idx = 18610
# Done
# idx = 18611
# Done
# idx = 18612
# Done
# idx = 18613
# Done
# idx = 18614
# Done
# idx = 18615
# Done
# idx = 18616
# Done
# idx = 18617
# Done
# idx = 18618
# Done
# idx = 18619
# Done
# idx = 18620
# Done
# idx = 18621
# Done
# idx = 18622
# Done
# idx = 18623
# Done
# idx = 18624
# Done
# idx = 18625
# Done
# idx = 18626
# Done
# idx = 18627
# Done
# idx = 18628
# Done
# idx = 18629
# Done
# idx = 18630
# Done
# idx = 18631
# Done
# idx = 18632
# Done
# idx = 18633
# Done
# idx = 18634
# Done
# idx = 18635
# Done
# idx = 18636
# Done
# idx = 18637
# Done
# idx = 18638
# Done
# idx = 18639
# Done
# idx = 18640
# Done
# idx = 18641
# Done
# idx = 18642
# Done
# idx = 18643
# Done
# idx = 18644
# Done
# idx = 18645
# Done
# idx = 18646
# Done
# idx = 18647
# Done
# idx = 18648
# Done
# idx = 18649
# Done
# idx = 18650
# Done
# idx = 18651
# Done
# idx = 18652
# Done
# idx = 18653
# Done
# idx = 18654
# Done
# idx = 18655
# Done
# idx = 18656
# Done
# idx = 18657
# Done
# idx = 18658
# Done
# idx = 18659
# Done
# idx = 18660
# Done
# idx = 18661
# Done
# idx = 18662
# Done
# idx = 18663
# Done
# idx = 18664
# Done
# idx = 18665
# Done
# idx = 18666
# Done
# idx = 18667
# Done
# idx = 18668
# Done
# idx = 18669
# Done
# idx = 18670
# Done
# idx = 18671
# Done
# idx = 18672
# Done
# idx = 18673
# Done
# idx = 18674
# Done
# idx = 18675
# Done
# idx = 18676
# Done
# idx = 18677
# Done
# idx = 18678
# Done
# idx = 18679
# Done
# idx = 18680
# Done
# idx = 18681
# Done
# idx = 18682
# Done
# idx = 18683
# Done
# idx = 18684
# Done
# idx = 18685
# Done
# idx = 18686
# Done
# idx = 18687
# Done
# idx = 18688
# Done
# idx = 18689
# Done
# idx = 18690
# Done
# idx = 18691
# Done
# idx = 18692
# Done
# idx = 18693
# Done
# idx = 18694
# Done
# idx = 18695
# Done
# idx = 18696
# Done
# idx = 18697
# Done
# idx = 18698
# Done
# idx = 18699
# Done
# idx = 18700
# Done
# idx = 18701
# Done
# idx = 18702
# Done
# idx = 18703
# Done
# idx = 18704
# Done
# idx = 18705
# Done
# idx = 18706
# Done
# idx = 18707
# Done
# idx = 18708
# Done
# idx = 18709
# Done
# idx = 18710
# Done
# idx = 18711
# Done
# idx = 18712
# Done
# idx = 18713
# Done
# idx = 18714
# Done
# idx = 18715
# Done
# idx = 18716
# Done
# idx = 18717
# Done
# idx = 18718
# Done
# idx = 18719
# Done
# idx = 18720
# Done
# idx = 18721
# Done
# idx = 18722
# Done
# idx = 18723
# Done
# idx = 18724
# Done
# idx = 18725
# Done
# idx = 18726
# Done
# idx = 18727
# Done
# idx = 18728
# Done
# idx = 18729
# Done
# idx = 18730
# Done
# idx = 18731
# Done
# idx = 18732
# Done
# idx = 18733
# Done
# idx = 18734
# Done
# idx = 18735
# Done
# idx = 18736
# Done
# idx = 18737
# Done
# idx = 18738
# Done
# idx = 18739
# Done
# idx = 18740
# Done
# idx = 18741
# Done
# idx = 18742
# Done
# idx = 18743
# Done
# idx = 18744
# Done
# idx = 18745
# Done
# idx = 18746
# Done
# idx = 18747
# Done
# idx = 18748
# Done
# idx = 18749
# Done
# idx = 18750
# Done
# idx = 18751
# Done
# idx = 18752
# Done
# idx = 18753
# Done
# idx = 18754
# Done
# idx = 18755
# Done
# idx = 18756
# Done
# idx = 18757
# Done
# idx = 18758
# Done
# idx = 18759
# Done

# %%
print("con_error =", len(con_error))
print("con =", len(con))
print(num - len(con))
# Out:
# con_error = 18763
# con = 18760
# 0

# %%
print("con_error =", len(con_error))
con_retry = [news_url[idx] for idx, i in con_error if i == 1 or i == 3]
print(len(con_retry))
print("="*25)
for idx, u in con_retry:
    print(idx, end=" ")
# Out:
# con_error = 18763
# 53
# =========================
# 248 678 783 907 1031 1309 2184 2452 2713 2938 2944 2948 3020 3246 3258 3455 4383 4432 4434 4490 4504 4546 4563 5091 5181 5374 5681 5730 6316 6602 6608 6644 6824 7195 7296 7495 7616 7866 8057 9528 10982 12230 12828 12854 13264 13304 13376 16366 16438 17076 17184 18138 18257

# %%
con_error2 = []

# %%
for idx, u in con_retry:
    print("idx =", idx)
    headers = {'User-agent' : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/113.0.0.0 Safari/537.36'}
    try:
        html = requests.get(u, headers = headers, timeout = 5)
    except:
        print("TimeOut ERROR")
        con[idx][1] = " "
        df = pd.DataFrame(con, columns = ["idx",'Contents'])
        df.to_csv(folder2 + '/df_con' + str(idx) + '.csv', encoding = 'utf-8-sig')
        con_error2.append((idx, 3))
        time.sleep(300)
    else:
        time.sleep(1)
        bs_obj = bs4.BeautifulSoup(html.content, "html.parser")
        body = bs_obj.find("div", {"id":"newsct_article","class":"newsct_article _article_body"})
        if body != None:
            contents = body.text.replace('\n','')
            if len(contents) == 0:
                print("ERROR2")
                title = bs_obj.find("h2", {"id":"title_area", "class":"media_end_head_headline"})
                con[idx][1] = title.text
                df = pd.DataFrame(con, columns = ["idx",'Contents'])
                df.to_csv(folder2 + '/df_con' + str(idx) + '.csv', encoding = 'utf-8-sig')
                con_error2.append((idx, 2))
                continue
            else: con[idx][1] = contents
        else:
            print("ERROR1")
            df = pd.DataFrame(con, columns = ["idx",'Contents'])
            df.to_csv(folder2 + '/df_con' + str(idx) + '.csv', encoding = 'utf-8-sig')
            con_error2.append((idx, 1))
            continue
        print("Done")
        con_error2.append((idx, 0))
# Out:
# idx = 248
# Done
# idx = 678
# Done
# idx = 783
# Done
# idx = 907
# Done
# idx = 1031
# Done
# idx = 1309
# Done
# idx = 2184
# Done
# idx = 2452
# Done
# idx = 2713
# Done
# idx = 2938
# Done
# idx = 2944
# Done
# idx = 2948
# Done
# idx = 3020
# Done
# idx = 3246
# Done
# idx = 3258
# Done
# idx = 3455
# Done
# idx = 4383
# Done
# idx = 4432
# Done
# idx = 4434
# Done
# idx = 4490
# Done
# idx = 4504
# Done
# idx = 4546
# Done
# idx = 4563
# Done
# idx = 5091
# Done
# idx = 5181
# Done
# idx = 5374
# Done
# idx = 5681
# Done
# idx = 5730
# Done
# idx = 6316
# ERROR1
# idx = 6602
# Done
# idx = 6608
# Done
# idx = 6644
# Done
# idx = 6824
# Done
# idx = 7195
# Done
# idx = 7296
# Done
# idx = 7495
# Done
# idx = 7616
# Done
# idx = 7866
# ERROR1
# idx = 8057
# Done
# idx = 9528
# Done
# idx = 10982
# Done
# idx = 12230
# Done
# idx = 12828
# Done
# idx = 12854
# Done
# idx = 13264
# Done
# idx = 13304
# Done
# idx = 13376
# Done
# idx = 16366
# ERROR1
# idx = 16438
# Done
# idx = 17076
# Done
# idx = 17184
# Done
# idx = 18138
# Done
# idx = 18257
# Done

# %%
len(con)
# Out:
# 18760

# %%
print("con_error2 =", len(con_error2))
con_retry2 = [con_retry[idx] for idx, i in enumerate(con_error2) if i[1] == 1 or i[1] == 3]
print(len(con_retry2))
print("="*25)
for idx, u in con_retry2:
    print(idx, end=" ")
# Out:
# con_error2 = 53
# 3
# =========================
# 6316 7866 16366

# %%
for idx, u in con_retry2:
    print("idx =", idx)
    headers = {'User-agent' : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/113.0.0.0 Safari/537.36'}
    try:
        html = requests.get(u, headers = headers, timeout = 5)
    except:
        print("TimeOut ERROR")
        con[idx][1] = " "
        df = pd.DataFrame(con, columns = ["idx",'Contents'])
        df.to_csv(folder2 + '/df_con' + str(idx) + '.csv', encoding = 'utf-8-sig')
        #con_error2.append((idx, 3))
        time.sleep(300)
    else:
        time.sleep(1)
        bs_obj = bs4.BeautifulSoup(html.content, "html.parser")
        body = bs_obj.find("div", {"id":"articeBody","class":"article_body font1 size3"})
        if body != None:
            contents = body.text.replace('\n','')
            if len(contents) == 0:
                print("ERROR2")
                title = bs_obj.find("h2", {"id":"title_area", "class":"media_end_head_headline"})
                con[idx][1] = title.text
                df = pd.DataFrame(con, columns = ["idx",'Contents'])
                df.to_csv(folder2 + '/df_con' + str(idx) + '.csv', encoding = 'utf-8-sig')
                #con_error2.append((idx, 2))
            else: con[idx][1] = contents
        else:
            print("ERROR1")
            df = pd.DataFrame(con, columns = ["idx",'Contents'])
            df.to_csv(folder2 + '/df_con' + str(idx) + '.csv', encoding = 'utf-8-sig')
            #con_error2.append((idx, 1))
            continue
        print("Done")
        #con_error2.append((idx, 0))
# Out:
# idx = 6316
# ERROR1
# idx = 7866
# Done
# idx = 16366
# ERROR1

# %%
news_url[6316]
# Out:
# (6316, 'https://n.news.naver.com/article/437/0000268987?ntype=RANKING')

# %%
news_url[16366]
# Out:
# (16366, 'https://n.news.naver.com/article/469/0000686884?ntype=RANKING')

# %%
for idx, u in [(6316, 'https://n.news.naver.com/article/437/0000268987?ntype=RANKING')]:
    print("idx =", idx)
    headers = {'User-agent' : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/113.0.0.0 Safari/537.36'}
    try:
        html = requests.get(u, headers = headers, timeout = 5)
    except:
        print("TimeOut ERROR")
        con[idx][1] = " "
        df = pd.DataFrame(con, columns = ["idx",'Contents'])
        df.to_csv(folder2 + '/df_con' + str(idx) + '.csv', encoding = 'utf-8-sig')
        #con_error2.append((idx, 3))
        time.sleep(300)
    else:
        time.sleep(1)
        bs_obj = bs4.BeautifulSoup(html.content, "html.parser")
        body = bs_obj.find("div", {"id":"dic_area","class":"go_trans _article_content"})
        if body != None:
            contents = body.text.replace('\n','')
            if len(contents) == 0:
                print("ERROR2")
                title = bs_obj.find("h2", {"id":"title_area", "class":"media_end_head_headline"})
                con[idx][1] = title.text
                df = pd.DataFrame(con, columns = ["idx",'Contents'])
                df.to_csv(folder2 + '/df_con' + str(idx) + '.csv', encoding = 'utf-8-sig')
                #con_error2.append((idx, 2))
            else: con[idx][1] = contents
        else:
            print("ERROR1")
            df = pd.DataFrame(con, columns = ["idx",'Contents'])
            df.to_csv(folder2 + '/df_con' + str(idx) + '.csv', encoding = 'utf-8-sig')
            #con_error2.append((idx, 1))
            continue
        print("Done")
        #con_error2.append((idx, 0))
# Out:
# idx = 6316
# Done

# %%
for idx, u in [(16366, 'https://n.news.naver.com/article/469/0000686884?ntype=RANKING')]:
    print("idx =", idx)
    headers = {'User-agent' : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/113.0.0.0 Safari/537.36'}
    try:
        html = requests.get(u, headers = headers, timeout = 5)
    except:
        print("TimeOut ERROR")
        con[idx][1] = " "
        df = pd.DataFrame(con, columns = ["idx",'Contents'])
        df.to_csv(folder2 + '/df_con' + str(idx) + '.csv', encoding = 'utf-8-sig')
        #con_error2.append((idx, 3))
        time.sleep(300)
    else:
        time.sleep(1)
        bs_obj = bs4.BeautifulSoup(html.content, "html.parser")
        body = bs_obj.find("div", {"id":"newsEndContents","class":"news_end"})
        if body != None:
            contents = body.text.replace('\n','')
            if len(contents) == 0:
                print("ERROR2")
                title = bs_obj.find("h2", {"id":"title_area", "class":"media_end_head_headline"})
                con[idx][1] = title.text
                df = pd.DataFrame(con, columns = ["idx",'Contents'])
                df.to_csv(folder2 + '/df_con' + str(idx) + '.csv', encoding = 'utf-8-sig')
                #con_error2.append((idx, 2))
            else: con[idx][1] = contents
        else:
            print("ERROR1")
            df = pd.DataFrame(con, columns = ["idx",'Contents'])
            df.to_csv(folder2 + '/df_con' + str(idx) + '.csv', encoding = 'utf-8-sig')
            #con_error2.append((idx, 1))
            continue
        print("Done")
        #con_error2.append((idx, 0))
# Out:
# idx = 16366
# Done

# %%
for i in range(len(con)):
    if len(con[i][1]) <= 2:
        print("idx =", i)
# Out:
# idx = 3069

# %%
news_url[3069]
# Out:
# (3069, 'https://n.news.naver.com/article/421/0006550111?ntype=RANKING')

# %%
con[3069][1] = "[속보] 서울·인천·경기·충남 일대서 '미확인 비행체' 목격"
con[3069]
# Out:
# [3069, "[속보] 서울·인천·경기·충남 일대서 '미확인 비행체' 목격"]

# %%
len(con)
# Out:
# 18760

# %%
df_con = pd.DataFrame({"idx":list(range(len(con))), "Date":date, "Contents":[con[i][1] for i in range(len(con))]})
df_con
# Out:
#          idx      Date                                           Contents
# 0          0  20210505  남편이 스스로 옷을 다려 입기까지 걸린 시간 15년... '누가 혜택을 누리고 사는...
# 1          1  20210505  어마어마한 플라스틱 포장 용기들... 플라스틱 줄이기, 개인이 할 수 있는 방법은 ...
# 2          2  20210505  과거 언론 인터뷰서 정경심 허위 표창장 살피려고 "상장대장 봤다" 언급...1심 재...
# 3          3  20210505  학생들에게 들려준 영어말하기의 도전과제 '소통과 용기'에 대하여【오마이뉴스의 모토는...
# 4          4  20210505  대통령 부부 평창 도성초 어린이와 영상 만남... "놀이환경을 더 많이 조성·지원"...
# ...      ...       ...                                                ...
# 18755  18755  20221215  온라인 공모펀드의 순자산 비중이 지속 상승하고 있다(왼쪽 그래프). 송태헌 신한자산...
# 18756  18756  20221215  \t\t\t지난 2012년 한 외국계 게임사가 한국 문화재청과 '문화재지킴이 협약'...
# 18757  18757  20221215  \t\t\t미국 폐배터리 재활용업체 ‘레드우드머티리얼즈’(이하 레드우드)가 사우스캐...
# 18758  18758  20221215  김승연 한화그룹 회장이 대우조선해양 인수를 발표한 2008년 글로벌 경영전략 회의....
# 18759  18759  20221215  '로카 나누기 카드' 광고 스틸컷.(사진=롯데카드)금리 급등으로 카드사의 핵심 혜택...
#
# [18760 rows x 3 columns]

# %%
df_con.to_csv(foldert + "/df_con.csv", encoding = 'utf-8-sig')

# %%
# 날짜가 문자형이 아니라 int로 저장되어 있음
df_con[df_con["Date"] == 20210505]
# Out:
#      idx      Date                                           Contents
# 0      0  20210505  남편이 스스로 옷을 다려 입기까지 걸린 시간 15년... '누가 혜택을 누리고 사는...
# 1      1  20210505  어마어마한 플라스틱 포장 용기들... 플라스틱 줄이기, 개인이 할 수 있는 방법은 ...
# 2      2  20210505  과거 언론 인터뷰서 정경심 허위 표창장 살피려고 "상장대장 봤다" 언급...1심 재...
# 3      3  20210505  학생들에게 들려준 영어말하기의 도전과제 '소통과 용기'에 대하여【오마이뉴스의 모토는...
# 4      4  20210505  대통령 부부 평창 도성초 어린이와 영상 만남... "놀이환경을 더 많이 조성·지원"...
# ..   ...       ...                                                ...
# 160  160  20210505  [디지털데일리 최민지기자] 임혜숙 과학기술정보통신부 장관 후보자<사진>는 삼성전자‧...
# 161  161  20210505  디지털데일리가 퇴근 즈음해서 읽을 수 있는 [DD퇴근길] 코너를 마련했습니다. 혹시...
# 162  162  20210505  - 중국, 세계 스마트폰 및 5G폰 최대 시장 부상  - 삼성전자, 중국 연간 점유...
# 163  163  20210505    [디지털데일리 권하영기자] ‘한 번에 한 집만’ 배달하는 이른바 ‘단건 배달’ ...
# 164  164  20210505    [디지털데일리 권하영기자] 카카오톡이 5일 밤 갑작스러운 장애를 일으키면서 이용...
#
# [165 rows x 3 columns]

# %%
d[:5]
# Out:
# ['20210505', '20211025', '20221015', '20210304', '20210323']

# %%
# 날짜들이 문자형으로 저장되어있는 b의 원소들을 int로 바꿔줌
b2 = [int(i) for i in d]
b2[:5]
# Out:
# [20210505, 20211025, 20221015, 20210304, 20210323]

# %%
len(b2)
# Out:
# 114

# %%
b2
# Out:
# [20210505,
#  20211025,
#  20221015,
#  20210304,
#  20210323,
#  20210312,
#  20211018,
#  20221030,
#  20210325,
#  20210417,
#  20210412,
#  20210506,
#  20210402,
#  20211123,
#  20230129,
#  20211005,
#  20210607,
#  20210426,
#  20221230,
#  20210513,
#  20230420,
#  20220615,
#  20211214,
#  20220608,
#  20210531,
#  20220207,
#  20210520,
#  20210611,
#  20221004,
#  20220224,
#  20210716,
#  20220109,
#  20220708,
#  20220101,
#  20210911,
#  20220310,
#  20230509,
#  20211216,
#  20210617,
#  20210811,
#  20210710,
#  20210630,
#  20210812,
#  20230109,
#  20210703,
#  20210902,
#  20220211,
#  20210802,
#  20220122,
#  20211104,
#  20210728,
#  20210825,
#  20211201,
#  20220116,
#  20211204,
#  20220523,
#  20220911,
#  20220808,
#  20210830,
#  20220307,
#  20220616,
#  20211028,
#  20220222,
#  20211229,
#  20221129,
#  20211112,
#  20211008,
#  20210923,
#  20220830,
#  20210916,
#  20220514,
#  20220529,
#  20221006,
#  20221203,
#  20221115,
#  20220201,
#  20221228,
#  20220926,
#  20230117,
#  20220317,
#  20220630,
#  20220629,
#  20221106,
#  20230204,
#  20220507,
#  20220725,
#  20220401,
#  20230404,
#  20221122,
#  20220802,
#  20220421,
#  20220324,
#  20220410,
#  20221025,
#  20220905,
#  20230310,
#  20220416,
#  20230302,
#  20230209,
#  20220719,
#  20220819,
#  20220428,
#  20230419,
#  20230227,
#  20220916,
#  20230427,
#  20230222,
#  20230125,
#  20230322,
#  20230411,
#  20230324,
#  20220811,
#  20221213,
#  20221215]

# %%
# 반복문으로 날짜별 데이터프레임에 따라 형태소 분석
for i in range(len(b2)):
    print("i =", i, "Date =", b2[i])
    text = df_con[df_con["Date"] == b2[i]]["Contents"]
    text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
    
    tokenized_data_filtered=[]
    for j in text_filtered:
        temp = tagger.nouns(j)
        temp = [word for word in temp if len(word)>1]  ## 두글자 이상이면 포함, 리스트 함축
        temp = [word for word in temp if word not in stopwords]
        tokenized_data_filtered.append(temp)
    
    tokens=[]
    for k in tokenized_data_filtered:
        tokens.extend(k)

    num_top_tokens=100

    counted_tokens=Counter(tokens)
    top_keywords=dict(counted_tokens.most_common(num_top_tokens))
    tk_df = pd.DataFrame(list(top_keywords.items()), columns=['keywords','freq'])
    tk_df.to_csv(folder3 + "/tk_df" + str(i) + ".csv", encoding = "utf-8-sig")
    
    print("DONE")
# Out:
# i = 0 Date = 20210505
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE
# i = 1 Date = 20211025
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE
# i = 2 Date = 20221015
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE
# i = 3 Date = 20210304
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE
# i = 4 Date = 20210323
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE
# i = 5 Date = 20210312
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE
# i = 6 Date = 20211018
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE
# i = 7 Date = 20221030
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE
# i = 8 Date = 20210325
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE
# i = 9 Date = 20210417
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE
# i = 10 Date = 20210412
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE
# i = 11 Date = 20210506
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE
# i = 12 Date = 20210402
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE
# i = 13 Date = 20211123
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE
# i = 14 Date = 20230129
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE
# i = 15 Date = 20211005
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE
# i = 16 Date = 20210607
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE
# i = 17 Date = 20210426
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE
# i = 18 Date = 20221230
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE
# i = 19 Date = 20210513
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE
# i = 20 Date = 20230420
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE
# i = 21 Date = 20220615
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE
# i = 22 Date = 20211214
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE
# i = 23 Date = 20220608
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE
# i = 24 Date = 20210531
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE
# i = 25 Date = 20220207
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE
# i = 26 Date = 20210520
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE
# i = 27 Date = 20210611
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE
# i = 28 Date = 20221004
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE
# i = 29 Date = 20220224
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE
# i = 30 Date = 20210716
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE
# i = 31 Date = 20220109
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE
# i = 32 Date = 20220708
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE
# i = 33 Date = 20220101
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE
# i = 34 Date = 20210911
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE
# i = 35 Date = 20220310
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE
# i = 36 Date = 20230509
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE
# i = 37 Date = 20211216
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE
# i = 38 Date = 20210617
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE
# i = 39 Date = 20210811
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE
# i = 40 Date = 20210710
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE
# i = 41 Date = 20210630
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE
# i = 42 Date = 20210812
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE
# i = 43 Date = 20230109
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE
# i = 44 Date = 20210703
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE
# i = 45 Date = 20210902
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE
# i = 46 Date = 20220211
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE
# i = 47 Date = 20210802
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE
# i = 48 Date = 20220122
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE
# i = 49 Date = 20211104
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE
# i = 50 Date = 20210728
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE
# i = 51 Date = 20210825
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE
# i = 52 Date = 20211201
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE
# i = 53 Date = 20220116
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE
# i = 54 Date = 20211204
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE
# i = 55 Date = 20220523
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE
# i = 56 Date = 20220911
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE
# i = 57 Date = 20220808
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE
# i = 58 Date = 20210830
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE
# i = 59 Date = 20220307
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE
# i = 60 Date = 20220616
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE
# i = 61 Date = 20211028
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE
# i = 62 Date = 20220222
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE
# i = 63 Date = 20211229
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE
# i = 64 Date = 20221129
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE
# i = 65 Date = 20211112
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE
# i = 66 Date = 20211008
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE
# i = 67 Date = 20210923
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE
# i = 68 Date = 20220830
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE
# i = 69 Date = 20210916
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE
# i = 70 Date = 20220514
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE
# i = 71 Date = 20220529
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE
# i = 72 Date = 20221006
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE
# i = 73 Date = 20221203
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE
# i = 74 Date = 20221115
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE
# i = 75 Date = 20220201
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE
# i = 76 Date = 20221228
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE
# i = 77 Date = 20220926
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE
# i = 78 Date = 20230117
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE
# i = 79 Date = 20220317
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE
# i = 80 Date = 20220630
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE
# i = 81 Date = 20220629
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE
# i = 82 Date = 20221106
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE
# i = 83 Date = 20230204
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE
# i = 84 Date = 20220507
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE
# i = 85 Date = 20220725
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE
# i = 86 Date = 20220401
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE
# i = 87 Date = 20230404
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE
# i = 88 Date = 20221122
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE
# i = 89 Date = 20220802
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE
# i = 90 Date = 20220421
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE
# i = 91 Date = 20220324
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE
# i = 92 Date = 20220410
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE
# i = 93 Date = 20221025
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE
# i = 94 Date = 20220905
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE
# i = 95 Date = 20230310
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE
# i = 96 Date = 20220416
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE
# i = 97 Date = 20230302
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE
# i = 98 Date = 20230209
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE
# i = 99 Date = 20220719
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE
# i = 100 Date = 20220819
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE
# i = 101 Date = 20220428
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE
# i = 102 Date = 20230419
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE
# i = 103 Date = 20230227
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE
# i = 104 Date = 20220916
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE
# i = 105 Date = 20230427
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE
# i = 106 Date = 20230222
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE
# i = 107 Date = 20230125
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE
# i = 108 Date = 20230322
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE
# i = 109 Date = 20230411
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE
# i = 110 Date = 20230324
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE
# i = 111 Date = 20220811
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE
# i = 112 Date = 20221213
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE
# i = 113 Date = 20221215
# C:\Users\inven\AppData\Local\Temp\ipykernel_8060\4131932175.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_filtered = text.str.replace("[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]"," ")
# DONE

# %%
tk_df
# Out:
#    keywords  freq
# 0        김씨   216
# 1        검찰   142
# 2        대표   137
# 3       대장동   133
# 4        의원   124
# ..      ...   ...
# 95       일부    40
# 96       국민    40
# 97       이유    39
# 98      본부장    39
# 99       장관    39
#
# [100 rows x 2 columns]

# %%
top = pd.DataFrame()
for i in range(len(b2)):
    tk = pd.read_csv(folder3 + "/tk_df" + str(i) + ".csv", encoding="utf-8-sig", index_col = 0)
    tk["freq"] *= w[i]
    top = pd.concat([top, tk], ignore_index = True)

# %%
top
# Out:
#       keywords        freq
# 0           백신  205.000000
# 1           손씨  188.000000
# 2           경찰  171.000000
# 3           서울  143.000000
# 4          아버지  137.000000
# ...        ...         ...
# 11395       일부    0.739052
# 11396       국민    0.739052
# 11397       이유    0.720576
# 11398      본부장    0.720576
# 11399       장관    0.720576
#
# [11400 rows x 2 columns]

# %%
r2 = top.groupby('keywords')['freq'].sum()
r3 = r2.sort_values(ascending = False)[:100]
r3.to_csv(foldert + "/freq.csv", encoding="utf-8-sig")
# keyword열을 key로하는 딕셔너리 생성
r4 = r3.T.to_dict()
r4
# Out:
# {'후보': 2271.5648978,
#  '대통령': 1462.0440991,
#  '서울': 1423.912423,
#  '사람': 1371.074649,
#  '경찰': 1245.7608668,
#  '정부': 1208.5024908,
#  '의원': 1165.8479854,
#  '백신': 1159.7247968,
#  '대표': 1152.9412192,
#  '상황': 1145.7246762,
#  '문제': 1011.1290012,
#  '당시': 1008.0550928,
#  '경우': 1005.3680853,
#  '생각': 958.3069648,
#  '국민의힘': 951.9901763,
#  '확인': 936.6912525,
#  '미국': 929.6594541,
#  '발생': 925.7836298,
#  '이상': 921.4730116,
#  '시간': 875.7985673,
#  '주장': 875.1206798,
#  '우리': 841.4466907,
#  '관련': 838.4028563,
#  '이번': 836.3215015,
#  '조사': 810.161456,
#  '지난해': 801.2437917999999,
#  '자신': 786.0497935,
#  '진행': 774.783485,
#  '결과': 765.0824396,
#  '시작': 747.671842,
#  '모습': 740.2300443,
#  '설명': 732.4878672,
#  '윤석열': 719.092986,
#  '시장': 710.8706324,
#  '해당': 710.0601739,
#  '접종': 692.9925204,
#  '공개': 654.9632263999999,
#  '사건': 627.5840688,
#  '정도': 572.6361239,
#  '내용': 565.4600324,
#  '사실': 563.9587086,
#  '의혹': 557.1906326,
#  '필요': 531.1444931999999,
#  '수사': 525.6103862,
#  '이유': 524.4038924,
#  '억원': 522.2441424,
#  '중국': 513.5051145,
#  '검찰': 512.7054067,
#  '혐의': 506.2893743,
#  '이재명': 495.1875812,
#  '일부': 444.1523952,
#  '보도': 443.2249402,
#  '민주당': 442.5956791,
#  '비판': 430.7078769,
#  '여성': 427.2396645,
#  '대선': 424.5546301,
#  '가능성': 419.5889727,
#  '총장': 411.9551375,
#  '입장': 409.1032759,
#  '관계자': 406.174641,
#  '한국': 404.0502701,
#  '영상': 384.8695762,
#  '사용': 383.7047721,
#  '올해': 380.319233,
#  '지적': 373.7440588,
#  '국내': 370.582481,
#  '일본': 370.29819119999996,
#  '장관': 369.6044006,
#  '아이': 368.09813379999997,
#  '상태': 365.5805336,
#  '서비스': 363.77321,
#  '무단전재': 358.069089,
#  '기준': 346.4117407,
#  '삼성전자': 345.0221718,
#  '발견': 337.1117907,
#  '지난달': 332.9165236,
#  '국민': 323.7535766,
#  '과정': 316.8111312,
#  '발표': 308.5962426,
#  '교수': 304.3392588,
#  '검사': 294.8854988,
#  '경기': 290.1002069,
#  '가운데': 288.714138,
#  '지역': 278.5049565,
#  '예정': 277.9236481,
#  '기사': 258.9815744,
#  '손씨': 253.4625323,
#  '확진자': 249.3759248,
#  '대상': 247.7430858,
#  '남성': 245.3070239,
#  '현장': 245.2225155,
#  '차량': 245.1149957,
#  '카카오': 241.31581229999998,
#  '무단': 235.2215416,
#  '이야기': 231.7832311,
#  '더불어민주당': 229.0273399,
#  '친구': 227.2354092,
#  '전재': 226.1805569,
#  '사망': 225.9193877,
#  '가격': 225.0158137}

# %%
# 워드클라우드 생성
wc = WordCloud(font_path='malgun',width=2000, height=1000,background_color='white',colormap='Dark2',random_state=2)
wc.generate_from_frequencies(r4)

fig=plt.figure()
fig.set_size_inches(10,10)

plt.axis('off')
plt.imshow(wc)
plt.savefig(foldert + '/result1.png')

# %% [markdown]
# ---

# %% [markdown]
# ---
